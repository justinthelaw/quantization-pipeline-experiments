# %% [markdown]
# ## GPTQModel Pipeline

# %% [markdown]
# ### Install GPTQModel

# %%
# clone GPTQModel repo
# !git clone --depth 1 --branch v0.9.9 https://github.com/ModelCloud/GPTQModel.git

# compile and install GPTQModel
# !cd GPTQModel && pip install --no-build-isolation .

# %% [markdown]
# ### Simple GPTQ Quantization
#
# Using the VMWare OPen Instruct dataset and NousResearch's Hermes 2 Pro Mistral 7B fine-tune.

# %%
import torch
import logging
from gptqmodel import GPTQModel, QuantizeConfig
from transformers import AutoTokenizer
from datasets import load_dataset


pretrained_model_id = "NousResearch/Hermes-2-Pro-Mistral-7B"
quantized_model_id = "NousResearch/Hermes-2-Pro-Mistral-7B-4bit-32g"


def get_open_instruct(tokenizer, nsamples, seqlen):
    traindata = load_dataset("VMware/open-instruct", "default", split="train").filter(
        lambda x: len(x["response"]) >= seqlen
    )

    return [tokenizer(example["response"]) for example in traindata.select(range(nsamples))]


def main():
    tokenizer = AutoTokenizer.from_pretrained(pretrained_model_id, use_fast=True)

    print("Loading Open Instruct training data...")
    train_dataset = get_open_instruct(tokenizer, nsamples=512, seqlen=1024)
    print("Completed loading of Open Instruct training data!")

    quantize_config = QuantizeConfig(
        # quantize model to 4-bit
        bits=4,
        # 128 offer good balance between inference speed and quantization quality
        # 32 will increase vRAM usage but increase inferencing quality
        group_size=32,
        # increase damp if NaN is encountered during `.quantize()` and/or increase calibration dataset size
        damp_percent=0.005,
        desc_act=True,
        static_groups=False,
        sym=True,
        true_sequential=True,
        lm_head=False,
        # marlin is vLLM's preferred GPTQ quantization method, which is included in "gptq"
        quant_method="gptq",
    )

    # load un-quantized model, the model will always be force loaded into cpu
    model = GPTQModel.from_pretrained(pretrained_model_id, quantize_config)

    print("Beginning quantization...")
    # quantize model, the calibration_dataset should be list of dict whose keys can only be "input_ids" and "attention_mask"
    # with value under torch.LongTensor type.
    model.quantize(train_dataset)
    print("Quantization complete!")

    print("Saving quantized model...")
    # save quantized model
    model.save_quantized(quantized_model_id)
    # save quantized model using safetensors
    model.save_quantized(quantized_model_id, use_safetensors=True, max_shard_size="4Gb")
    print("Saving quantized model complete!")

    # load quantized model, currently only support cpu or single gpu
    model = GPTQModel.from_quantized(quantized_model_id, device="cuda:0")

    # inference with model.generate
    print(
        tokenizer.decode(
            model.generate(
                **tokenizer("What is the capital of Jamaica?", return_tensors="pt").to(
                    "cuda:0"
                )
            )[0]
        )
    )

# set logging configuration for GPTQModel
logging.basicConfig(
    format="%(asctime)s %(levelname)s [%(name)s] %(message)s",
    level=logging.INFO,
    datefmt="%Y-%m-%d %H:%M:%S",
)

# execute main method
main()
# Out:
# Loading Open Instruct training data...
# Completed loading of Open Instruct training data!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING - Model config does not have pad token mapped. Please pass in tokenizer to `quantize()` so GPTQModel can auto-select the best pad token.
# Beginning quantization...
# Quantizing self_attn.k_proj in layer 1 of 32:   0%|          | 0/32 [00:06<?, ?it/s]INFO - {'layer': 1, 'module': 'self_attn.k_proj', 'avg_loss': '0.0241', 'time': '1.6384'}
# Quantizing self_attn.v_proj in layer 1 of 32:   0%|          | 0/32 [00:08<?, ?it/s]INFO - {'layer': 1, 'module': 'self_attn.v_proj', 'avg_loss': '0.0011', 'time': '1.6030'}
# Quantizing self_attn.q_proj in layer 1 of 32:   0%|          | 0/32 [00:09<?, ?it/s]INFO - {'layer': 1, 'module': 'self_attn.q_proj', 'avg_loss': '0.0933', 'time': '1.6508'}
# Quantizing self_attn.o_proj in layer 1 of 32:   0%|          | 0/32 [00:15<?, ?it/s]INFO - {'layer': 1, 'module': 'self_attn.o_proj', 'avg_loss': '0.0000', 'time': '1.6612'}
# Quantizing mlp.up_proj in layer 1 of 32:   0%|          | 0/32 [00:22<?, ?it/s]     INFO - {'layer': 1, 'module': 'mlp.up_proj', 'avg_loss': '0.0931', 'time': '1.8252'}
# Quantizing mlp.gate_proj in layer 1 of 32:   0%|          | 0/32 [00:23<?, ?it/s]INFO - {'layer': 1, 'module': 'mlp.gate_proj', 'avg_loss': '0.1032', 'time': '1.7496'}
# Quantizing mlp.down_proj in layer 1 of 32:   0%|          | 0/32 [00:44<?, ?it/s]INFO - {'layer': 1, 'module': 'mlp.down_proj', 'avg_loss': '0.0001', 'time': '7.0378'}
# Quantizing self_attn.k_proj in layer 2 of 32:   3%|▎         | 1/32 [01:00<27:56, 54.08s/it]INFO - {'layer': 2, 'module': 'self_attn.k_proj', 'avg_loss': '0.0859', 'time': '1.7096'}
# Quantizing self_attn.v_proj in layer 2 of 32:   3%|▎         | 1/32 [01:02<27:56, 54.08s/it]INFO - {'layer': 2, 'module': 'self_attn.v_proj', 'avg_loss': '0.0092', 'time': '1.6594'}
# Quantizing self_attn.q_proj in layer 2 of 32:   3%|▎         | 1/32 [01:03<27:56, 54.08s/it]INFO - {'layer': 2, 'module': 'self_attn.q_proj', 'avg_loss': '0.1904', 'time': '1.6806'}
# Quantizing self_attn.o_proj in layer 2 of 32:   3%|▎         | 1/32 [01:09<27:56, 54.08s/it]INFO - {'layer': 2, 'module': 'self_attn.o_proj', 'avg_loss': '0.0001', 'time': '1.6936'}
# Quantizing mlp.up_proj in layer 2 of 32:   3%|▎         | 1/32 [01:16<27:56, 54.08s/it]     INFO - {'layer': 2, 'module': 'mlp.up_proj', 'avg_loss': '0.3032', 'time': '1.7735'}
# Quantizing mlp.gate_proj in layer 2 of 32:   3%|▎         | 1/32 [01:17<27:56, 54.08s/it]INFO - {'layer': 2, 'module': 'mlp.gate_proj', 'avg_loss': '0.3401', 'time': '1.7592'}
# Quantizing mlp.down_proj in layer 2 of 32:   3%|▎         | 1/32 [01:37<27:56, 54.08s/it]INFO - {'layer': 2, 'module': 'mlp.down_proj', 'avg_loss': '0.0597', 'time': '7.0816'}
# Quantizing self_attn.k_proj in layer 3 of 32:   6%|▋         | 2/32 [01:54<26:54, 53.83s/it]INFO - {'layer': 3, 'module': 'self_attn.k_proj', 'avg_loss': '0.7164', 'time': '1.6581'}
# Quantizing self_attn.v_proj in layer 3 of 32:   6%|▋         | 2/32 [01:55<26:54, 53.83s/it]INFO - {'layer': 3, 'module': 'self_attn.v_proj', 'avg_loss': '0.0660', 'time': '1.6376'}
# Quantizing self_attn.q_proj in layer 3 of 32:   6%|▋         | 2/32 [01:57<26:54, 53.83s/it]INFO - {'layer': 3, 'module': 'self_attn.q_proj', 'avg_loss': '1.3538', 'time': '1.6700'}
# Quantizing self_attn.o_proj in layer 3 of 32:   6%|▋         | 2/32 [02:02<26:54, 53.83s/it]INFO - {'layer': 3, 'module': 'self_attn.o_proj', 'avg_loss': '0.0001', 'time': '1.6813'}
# Quantizing mlp.up_proj in layer 3 of 32:   6%|▋         | 2/32 [02:09<26:54, 53.83s/it]     INFO - {'layer': 3, 'module': 'mlp.up_proj', 'avg_loss': '0.7558', 'time': '1.7666'}
# Quantizing mlp.gate_proj in layer 3 of 32:   6%|▋         | 2/32 [02:11<26:54, 53.83s/it]INFO - {'layer': 3, 'module': 'mlp.gate_proj', 'avg_loss': '0.8540', 'time': '1.7515'}
# Quantizing mlp.down_proj in layer 3 of 32:   6%|▋         | 2/32 [02:31<26:54, 53.83s/it]INFO - {'layer': 3, 'module': 'mlp.down_proj', 'avg_loss': '0.0003', 'time': '7.0831'}
# Quantizing self_attn.k_proj in layer 4 of 32:   9%|▉         | 3/32 [02:47<26:00, 53.80s/it]INFO - {'layer': 4, 'module': 'self_attn.k_proj', 'avg_loss': '0.4896', 'time': '1.6663'}
# Quantizing self_attn.v_proj in layer 4 of 32:   9%|▉         | 3/32 [02:49<26:00, 53.80s/it]INFO - {'layer': 4, 'module': 'self_attn.v_proj', 'avg_loss': '0.0743', 'time': '1.6931'}
# Quantizing self_attn.q_proj in layer 4 of 32:   9%|▉         | 3/32 [02:51<26:00, 53.80s/it]INFO - {'layer': 4, 'module': 'self_attn.q_proj', 'avg_loss': '0.9487', 'time': '1.6856'}
# Quantizing self_attn.o_proj in layer 4 of 32:   9%|▉         | 3/32 [02:56<26:00, 53.80s/it]INFO - {'layer': 4, 'module': 'self_attn.o_proj', 'avg_loss': '0.0002', 'time': '1.6871'}
# Quantizing mlp.up_proj in layer 4 of 32:   9%|▉         | 3/32 [03:03<26:00, 53.80s/it]     INFO - {'layer': 4, 'module': 'mlp.up_proj', 'avg_loss': '1.1813', 'time': '1.7723'}
# Quantizing mlp.gate_proj in layer 4 of 32:   9%|▉         | 3/32 [03:05<26:00, 53.80s/it]INFO - {'layer': 4, 'module': 'mlp.gate_proj', 'avg_loss': '1.3529', 'time': '1.7623'}
# Quantizing mlp.down_proj in layer 4 of 32:   9%|▉         | 3/32 [03:25<26:00, 53.80s/it]INFO - {'layer': 4, 'module': 'mlp.down_proj', 'avg_loss': '0.0006', 'time': '7.1264'}
# Quantizing self_attn.k_proj in layer 5 of 32:  12%|█▎        | 4/32 [03:41<25:06, 53.81s/it]INFO - {'layer': 5, 'module': 'self_attn.k_proj', 'avg_loss': '0.7491', 'time': '1.6673'}
# Quantizing self_attn.v_proj in layer 5 of 32:  12%|█▎        | 4/32 [03:43<25:06, 53.81s/it]INFO - {'layer': 5, 'module': 'self_attn.v_proj', 'avg_loss': '0.1344', 'time': '1.6446'}
# Quantizing self_attn.q_proj in layer 5 of 32:  12%|█▎        | 4/32 [03:45<25:06, 53.81s/it]INFO - {'layer': 5, 'module': 'self_attn.q_proj', 'avg_loss': '1.6472', 'time': '1.6620'}
# Quantizing self_attn.o_proj in layer 5 of 32:  12%|█▎        | 4/32 [03:50<25:06, 53.81s/it]INFO - {'layer': 5, 'module': 'self_attn.o_proj', 'avg_loss': '0.0002', 'time': '1.6904'}
# Quantizing mlp.up_proj in layer 5 of 32:  12%|█▎        | 4/32 [03:57<25:06, 53.81s/it]     INFO - {'layer': 5, 'module': 'mlp.up_proj', 'avg_loss': '1.5898', 'time': '1.7598'}
# Quantizing mlp.gate_proj in layer 5 of 32:  12%|█▎        | 4/32 [03:59<25:06, 53.81s/it]INFO - {'layer': 5, 'module': 'mlp.gate_proj', 'avg_loss': '1.9363', 'time': '1.7470'}
# Quantizing mlp.down_proj in layer 5 of 32:  12%|█▎        | 4/32 [04:19<25:06, 53.81s/it]INFO - {'layer': 5, 'module': 'mlp.down_proj', 'avg_loss': '0.0011', 'time': '7.0637'}
# Quantizing self_attn.k_proj in layer 6 of 32:  16%|█▌        | 5/32 [04:35<24:12, 53.79s/it]INFO - {'layer': 6, 'module': 'self_attn.k_proj', 'avg_loss': '1.0580', 'time': '1.6672'}
# Quantizing self_attn.v_proj in layer 6 of 32:  16%|█▌        | 5/32 [04:37<24:12, 53.79s/it]INFO - {'layer': 6, 'module': 'self_attn.v_proj', 'avg_loss': '0.1945', 'time': '1.6453'}
# Quantizing self_attn.q_proj in layer 6 of 32:  16%|█▌        | 5/32 [04:38<24:12, 53.79s/it]INFO - {'layer': 6, 'module': 'self_attn.q_proj', 'avg_loss': '2.3354', 'time': '1.6734'}
# Quantizing self_attn.o_proj in layer 6 of 32:  16%|█▌        | 5/32 [04:44<24:12, 53.79s/it]INFO - {'layer': 6, 'module': 'self_attn.o_proj', 'avg_loss': '0.0006', 'time': '1.6832'}
# Quantizing mlp.up_proj in layer 6 of 32:  16%|█▌        | 5/32 [04:50<24:12, 53.79s/it]     INFO - {'layer': 6, 'module': 'mlp.up_proj', 'avg_loss': '2.1299', 'time': '1.7844'}
# Quantizing mlp.gate_proj in layer 6 of 32:  16%|█▌        | 5/32 [04:52<24:12, 53.79s/it]INFO - {'layer': 6, 'module': 'mlp.gate_proj', 'avg_loss': '2.7614', 'time': '1.7482'}
# Quantizing mlp.down_proj in layer 6 of 32:  16%|█▌        | 5/32 [05:12<24:12, 53.79s/it]INFO - {'layer': 6, 'module': 'mlp.down_proj', 'avg_loss': '0.0020', 'time': '7.0896'}
# Quantizing self_attn.k_proj in layer 7 of 32:  19%|█▉        | 6/32 [05:29<23:17, 53.75s/it]INFO - {'layer': 7, 'module': 'self_attn.k_proj', 'avg_loss': '1.0519', 'time': '1.7210'}
# Quantizing self_attn.v_proj in layer 7 of 32:  19%|█▉        | 6/32 [05:30<23:17, 53.75s/it]INFO - {'layer': 7, 'module': 'self_attn.v_proj', 'avg_loss': '0.1847', 'time': '1.6362'}
# Quantizing self_attn.q_proj in layer 7 of 32:  19%|█▉        | 6/32 [05:32<23:17, 53.75s/it]INFO - {'layer': 7, 'module': 'self_attn.q_proj', 'avg_loss': '2.2436', 'time': '1.6745'}
# Quantizing self_attn.o_proj in layer 7 of 32:  19%|█▉        | 6/32 [05:37<23:17, 53.75s/it]INFO - {'layer': 7, 'module': 'self_attn.o_proj', 'avg_loss': '0.0006', 'time': '1.7041'}
# Quantizing mlp.up_proj in layer 7 of 32:  19%|█▉        | 6/32 [05:44<23:17, 53.75s/it]     INFO - {'layer': 7, 'module': 'mlp.up_proj', 'avg_loss': '2.6336', 'time': '1.7700'}
# Quantizing mlp.gate_proj in layer 7 of 32:  19%|█▉        | 6/32 [05:46<23:17, 53.75s/it]INFO - {'layer': 7, 'module': 'mlp.gate_proj', 'avg_loss': '3.3696', 'time': '1.7505'}
# Quantizing mlp.down_proj in layer 7 of 32:  19%|█▉        | 6/32 [06:06<23:17, 53.75s/it]INFO - {'layer': 7, 'module': 'mlp.down_proj', 'avg_loss': '0.0028', 'time': '7.0521'}
# Quantizing self_attn.k_proj in layer 8 of 32:  22%|██▏       | 7/32 [06:22<22:23, 53.74s/it]INFO - {'layer': 8, 'module': 'self_attn.k_proj', 'avg_loss': '1.3770', 'time': '1.6533'}
# Quantizing self_attn.v_proj in layer 8 of 32:  22%|██▏       | 7/32 [06:24<22:23, 53.74s/it]INFO - {'layer': 8, 'module': 'self_attn.v_proj', 'avg_loss': '0.2127', 'time': '1.6473'}
# Quantizing self_attn.q_proj in layer 8 of 32:  22%|██▏       | 7/32 [06:26<22:23, 53.74s/it]INFO - {'layer': 8, 'module': 'self_attn.q_proj', 'avg_loss': '2.8355', 'time': '1.6638'}
# Quantizing self_attn.o_proj in layer 8 of 32:  22%|██▏       | 7/32 [06:31<22:23, 53.74s/it]INFO - {'layer': 8, 'module': 'self_attn.o_proj', 'avg_loss': '0.0012', 'time': '1.7156'}
# Quantizing mlp.up_proj in layer 8 of 32:  22%|██▏       | 7/32 [06:38<22:23, 53.74s/it]     INFO - {'layer': 8, 'module': 'mlp.up_proj', 'avg_loss': '3.2066', 'time': '1.7818'}
# Quantizing mlp.gate_proj in layer 8 of 32:  22%|██▏       | 7/32 [06:40<22:23, 53.74s/it]INFO - {'layer': 8, 'module': 'mlp.gate_proj', 'avg_loss': '4.1738', 'time': '1.7841'}
# Quantizing mlp.down_proj in layer 8 of 32:  22%|██▏       | 7/32 [07:00<22:23, 53.74s/it]INFO - {'layer': 8, 'module': 'mlp.down_proj', 'avg_loss': '0.0038', 'time': '7.0624'}
# Quantizing self_attn.k_proj in layer 9 of 32:  25%|██▌       | 8/32 [07:16<21:29, 53.74s/it]INFO - {'layer': 9, 'module': 'self_attn.k_proj', 'avg_loss': '1.1637', 'time': '1.6611'}
# Quantizing self_attn.v_proj in layer 9 of 32:  25%|██▌       | 8/32 [07:18<21:29, 53.74s/it]INFO - {'layer': 9, 'module': 'self_attn.v_proj', 'avg_loss': '0.2350', 'time': '1.6359'}
# Quantizing self_attn.q_proj in layer 9 of 32:  25%|██▌       | 8/32 [07:19<21:29, 53.74s/it]INFO - {'layer': 9, 'module': 'self_attn.q_proj', 'avg_loss': '2.5413', 'time': '1.6609'}
# Quantizing self_attn.o_proj in layer 9 of 32:  25%|██▌       | 8/32 [07:25<21:29, 53.74s/it]INFO - {'layer': 9, 'module': 'self_attn.o_proj', 'avg_loss': '0.0013', 'time': '1.6756'}
# Quantizing mlp.up_proj in layer 9 of 32:  25%|██▌       | 8/32 [07:32<21:29, 53.74s/it]     INFO - {'layer': 9, 'module': 'mlp.up_proj', 'avg_loss': '3.6303', 'time': '1.8260'}
# Quantizing mlp.gate_proj in layer 9 of 32:  25%|██▌       | 8/32 [07:33<21:29, 53.74s/it]INFO - {'layer': 9, 'module': 'mlp.gate_proj', 'avg_loss': '4.6187', 'time': '1.7430'}
# Quantizing mlp.down_proj in layer 9 of 32:  25%|██▌       | 8/32 [07:54<21:29, 53.74s/it]INFO - {'layer': 9, 'module': 'mlp.down_proj', 'avg_loss': '0.0046', 'time': '7.0796'}
# Quantizing self_attn.k_proj in layer 10 of 32:  28%|██▊       | 9/32 [08:10<20:36, 53.76s/it]INFO - {'layer': 10, 'module': 'self_attn.k_proj', 'avg_loss': '1.6795', 'time': '1.6592'}
# Quantizing self_attn.v_proj in layer 10 of 32:  28%|██▊       | 9/32 [08:12<20:36, 53.76s/it]INFO - {'layer': 10, 'module': 'self_attn.v_proj', 'avg_loss': '0.2979', 'time': '1.6417'}
# Quantizing self_attn.q_proj in layer 10 of 32:  28%|██▊       | 9/32 [08:13<20:36, 53.76s/it]INFO - {'layer': 10, 'module': 'self_attn.q_proj', 'avg_loss': '3.5786', 'time': '1.6734'}
# Quantizing self_attn.o_proj in layer 10 of 32:  28%|██▊       | 9/32 [08:19<20:36, 53.76s/it]INFO - {'layer': 10, 'module': 'self_attn.o_proj', 'avg_loss': '0.0016', 'time': '1.6831'}
# Quantizing mlp.up_proj in layer 10 of 32:  28%|██▊       | 9/32 [08:25<20:36, 53.76s/it]     INFO - {'layer': 10, 'module': 'mlp.up_proj', 'avg_loss': '3.9789', 'time': '1.7653'}
# Quantizing mlp.gate_proj in layer 10 of 32:  28%|██▊       | 9/32 [08:27<20:36, 53.76s/it]INFO - {'layer': 10, 'module': 'mlp.gate_proj', 'avg_loss': '4.8817', 'time': '1.7489'}
# Quantizing mlp.down_proj in layer 10 of 32:  28%|██▊       | 9/32 [08:47<20:36, 53.76s/it]INFO - {'layer': 10, 'module': 'mlp.down_proj', 'avg_loss': '0.0057', 'time': '7.0931'}
# Quantizing self_attn.k_proj in layer 11 of 32:  31%|███▏      | 10/32 [09:04<19:43, 53.80s/it]INFO - {'layer': 11, 'module': 'self_attn.k_proj', 'avg_loss': '1.4588', 'time': '1.6643'}
# Quantizing self_attn.v_proj in layer 11 of 32:  31%|███▏      | 10/32 [09:05<19:43, 53.80s/it]INFO - {'layer': 11, 'module': 'self_attn.v_proj', 'avg_loss': '0.2510', 'time': '1.6512'}
# Quantizing self_attn.q_proj in layer 11 of 32:  31%|███▏      | 10/32 [09:07<19:43, 53.80s/it]INFO - {'layer': 11, 'module': 'self_attn.q_proj', 'avg_loss': '3.1054', 'time': '1.6678'}
# Quantizing self_attn.o_proj in layer 11 of 32:  31%|███▏      | 10/32 [09:13<19:43, 53.80s/it]INFO - {'layer': 11, 'module': 'self_attn.o_proj', 'avg_loss': '0.0021', 'time': '1.6863'}
# Quantizing mlp.up_proj in layer 11 of 32:  31%|███▏      | 10/32 [09:19<19:43, 53.80s/it]     INFO - {'layer': 11, 'module': 'mlp.up_proj', 'avg_loss': '4.1272', 'time': '1.7652'}
# Quantizing mlp.gate_proj in layer 11 of 32:  31%|███▏      | 10/32 [09:21<19:43, 53.80s/it]INFO - {'layer': 11, 'module': 'mlp.gate_proj', 'avg_loss': '4.9501', 'time': '1.7512'}
# Quantizing mlp.down_proj in layer 11 of 32:  31%|███▏      | 10/32 [09:41<19:43, 53.80s/it]INFO - {'layer': 11, 'module': 'mlp.down_proj', 'avg_loss': '0.0063', 'time': '7.0967'}
# Quantizing self_attn.k_proj in layer 12 of 32:  34%|███▍      | 11/32 [09:58<18:50, 53.81s/it]INFO - {'layer': 12, 'module': 'self_attn.k_proj', 'avg_loss': '1.7348', 'time': '1.6646'}
# Quantizing self_attn.v_proj in layer 12 of 32:  34%|███▍      | 11/32 [09:59<18:50, 53.81s/it]INFO - {'layer': 12, 'module': 'self_attn.v_proj', 'avg_loss': '0.3818', 'time': '1.6479'}
# Quantizing self_attn.q_proj in layer 12 of 32:  34%|███▍      | 11/32 [10:01<18:50, 53.81s/it]INFO - {'layer': 12, 'module': 'self_attn.q_proj', 'avg_loss': '3.7540', 'time': '1.6787'}
# Quantizing self_attn.o_proj in layer 12 of 32:  34%|███▍      | 11/32 [10:06<18:50, 53.81s/it]INFO - {'layer': 12, 'module': 'self_attn.o_proj', 'avg_loss': '0.0032', 'time': '1.6881'}
# Quantizing mlp.up_proj in layer 12 of 32:  34%|███▍      | 11/32 [10:13<18:50, 53.81s/it]     INFO - {'layer': 12, 'module': 'mlp.up_proj', 'avg_loss': '4.5521', 'time': '1.7812'}
# Quantizing mlp.gate_proj in layer 12 of 32:  34%|███▍      | 11/32 [10:15<18:50, 53.81s/it]INFO - {'layer': 12, 'module': 'mlp.gate_proj', 'avg_loss': '5.3604', 'time': '1.7474'}
# Quantizing mlp.down_proj in layer 12 of 32:  34%|███▍      | 11/32 [10:35<18:50, 53.81s/it]INFO - {'layer': 12, 'module': 'mlp.down_proj', 'avg_loss': '0.0074', 'time': '7.0762'}
# Quantizing self_attn.k_proj in layer 13 of 32:  38%|███▊      | 12/32 [10:52<17:56, 53.83s/it]INFO - {'layer': 13, 'module': 'self_attn.k_proj', 'avg_loss': '2.1815', 'time': '1.6676'}
# Quantizing self_attn.v_proj in layer 13 of 32:  38%|███▊      | 12/32 [10:53<17:56, 53.83s/it]INFO - {'layer': 13, 'module': 'self_attn.v_proj', 'avg_loss': '0.4272', 'time': '1.6654'}
# Quantizing self_attn.q_proj in layer 13 of 32:  38%|███▊      | 12/32 [10:55<17:56, 53.83s/it]INFO - {'layer': 13, 'module': 'self_attn.q_proj', 'avg_loss': '4.7797', 'time': '1.6938'}
# Quantizing self_attn.o_proj in layer 13 of 32:  38%|███▊      | 12/32 [11:00<17:56, 53.83s/it]INFO - {'layer': 13, 'module': 'self_attn.o_proj', 'avg_loss': '0.0036', 'time': '1.6809'}
# Quantizing mlp.up_proj in layer 13 of 32:  38%|███▊      | 12/32 [11:07<17:56, 53.83s/it]     INFO - {'layer': 13, 'module': 'mlp.up_proj', 'avg_loss': '5.2774', 'time': '1.7791'}
# Quantizing mlp.gate_proj in layer 13 of 32:  38%|███▊      | 12/32 [11:09<17:56, 53.83s/it]INFO - {'layer': 13, 'module': 'mlp.gate_proj', 'avg_loss': '6.0589', 'time': '1.7466'}
# Quantizing mlp.down_proj in layer 13 of 32:  38%|███▊      | 12/32 [11:29<17:56, 53.83s/it]INFO - {'layer': 13, 'module': 'mlp.down_proj', 'avg_loss': '0.0095', 'time': '7.1135'}
# Quantizing self_attn.k_proj in layer 14 of 32:  41%|████      | 13/32 [11:45<17:03, 53.87s/it]INFO - {'layer': 14, 'module': 'self_attn.k_proj', 'avg_loss': '2.0238', 'time': '1.6578'}
# Quantizing self_attn.v_proj in layer 14 of 32:  41%|████      | 13/32 [11:47<17:03, 53.87s/it]INFO - {'layer': 14, 'module': 'self_attn.v_proj', 'avg_loss': '0.4410', 'time': '1.6488'}
# Quantizing self_attn.q_proj in layer 14 of 32:  41%|████      | 13/32 [11:49<17:03, 53.87s/it]INFO - {'layer': 14, 'module': 'self_attn.q_proj', 'avg_loss': '4.2040', 'time': '1.6649'}
# Quantizing self_attn.o_proj in layer 14 of 32:  41%|████      | 13/32 [11:54<17:03, 53.87s/it]INFO - {'layer': 14, 'module': 'self_attn.o_proj', 'avg_loss': '0.0047', 'time': '1.6968'}
# Quantizing mlp.up_proj in layer 14 of 32:  41%|████      | 13/32 [12:01<17:03, 53.87s/it]     INFO - {'layer': 14, 'module': 'mlp.up_proj', 'avg_loss': '6.0502', 'time': '1.7812'}
# Quantizing mlp.gate_proj in layer 14 of 32:  41%|████      | 13/32 [12:03<17:03, 53.87s/it]INFO - {'layer': 14, 'module': 'mlp.gate_proj', 'avg_loss': '6.7315', 'time': '1.7494'}
# Quantizing mlp.down_proj in layer 14 of 32:  41%|████      | 13/32 [12:23<17:03, 53.87s/it]INFO - {'layer': 14, 'module': 'mlp.down_proj', 'avg_loss': '0.0117', 'time': '7.0666'}
# Quantizing self_attn.k_proj in layer 15 of 32:  44%|████▍     | 14/32 [12:39<16:09, 53.86s/it]INFO - {'layer': 15, 'module': 'self_attn.k_proj', 'avg_loss': '2.0470', 'time': '1.6866'}
# Quantizing self_attn.v_proj in layer 15 of 32:  44%|████▍     | 14/32 [12:41<16:09, 53.86s/it]INFO - {'layer': 15, 'module': 'self_attn.v_proj', 'avg_loss': '0.6789', 'time': '1.6353'}
# Quantizing self_attn.q_proj in layer 15 of 32:  44%|████▍     | 14/32 [12:43<16:09, 53.86s/it]INFO - {'layer': 15, 'module': 'self_attn.q_proj', 'avg_loss': '4.7577', 'time': '1.6677'}
# Quantizing self_attn.o_proj in layer 15 of 32:  44%|████▍     | 14/32 [12:48<16:09, 53.86s/it]INFO - {'layer': 15, 'module': 'self_attn.o_proj', 'avg_loss': '0.0065', 'time': '1.6777'}
# Quantizing mlp.up_proj in layer 15 of 32:  44%|████▍     | 14/32 [12:55<16:09, 53.86s/it]     INFO - {'layer': 15, 'module': 'mlp.up_proj', 'avg_loss': '6.8091', 'time': '1.8100'}
# Quantizing mlp.gate_proj in layer 15 of 32:  44%|████▍     | 14/32 [12:57<16:09, 53.86s/it]INFO - {'layer': 15, 'module': 'mlp.gate_proj', 'avg_loss': '7.5331', 'time': '1.7539'}
# Quantizing mlp.down_proj in layer 15 of 32:  44%|████▍     | 14/32 [13:17<16:09, 53.86s/it]INFO - {'layer': 15, 'module': 'mlp.down_proj', 'avg_loss': '0.0152', 'time': '7.1111'}
# Quantizing self_attn.k_proj in layer 16 of 32:  47%|████▋     | 15/32 [13:33<15:15, 53.88s/it]INFO - {'layer': 16, 'module': 'self_attn.k_proj', 'avg_loss': '2.6365', 'time': '1.6579'}
# Quantizing self_attn.v_proj in layer 16 of 32:  47%|████▋     | 15/32 [13:35<15:15, 53.88s/it]INFO - {'layer': 16, 'module': 'self_attn.v_proj', 'avg_loss': '0.8908', 'time': '1.6393'}
# Quantizing self_attn.q_proj in layer 16 of 32:  47%|████▋     | 15/32 [13:37<15:15, 53.88s/it]INFO - {'layer': 16, 'module': 'self_attn.q_proj', 'avg_loss': '5.9490', 'time': '1.6615'}
# Quantizing self_attn.o_proj in layer 16 of 32:  47%|████▋     | 15/32 [13:42<15:15, 53.88s/it]INFO - {'layer': 16, 'module': 'self_attn.o_proj', 'avg_loss': '0.0076', 'time': '1.6970'}
# Quantizing mlp.up_proj in layer 16 of 32:  47%|████▋     | 15/32 [13:49<15:15, 53.88s/it]     INFO - {'layer': 16, 'module': 'mlp.up_proj', 'avg_loss': '7.8308', 'time': '1.7767'}
# Quantizing mlp.gate_proj in layer 16 of 32:  47%|████▋     | 15/32 [13:51<15:15, 53.88s/it]INFO - {'layer': 16, 'module': 'mlp.gate_proj', 'avg_loss': '8.9347', 'time': '1.7387'}
# Quantizing mlp.down_proj in layer 16 of 32:  47%|████▋     | 15/32 [14:11<15:15, 53.88s/it]INFO - {'layer': 16, 'module': 'mlp.down_proj', 'avg_loss': '0.0199', 'time': '7.0743'}
# Quantizing self_attn.k_proj in layer 17 of 32:  50%|█████     | 16/32 [14:27<14:21, 53.87s/it]INFO - {'layer': 17, 'module': 'self_attn.k_proj', 'avg_loss': '2.6732', 'time': '1.6637'}
# Quantizing self_attn.v_proj in layer 17 of 32:  50%|█████     | 16/32 [14:29<14:21, 53.87s/it]INFO - {'layer': 17, 'module': 'self_attn.v_proj', 'avg_loss': '0.8127', 'time': '1.6456'}
# Quantizing self_attn.q_proj in layer 17 of 32:  50%|█████     | 16/32 [14:30<14:21, 53.87s/it]INFO - {'layer': 17, 'module': 'self_attn.q_proj', 'avg_loss': '5.8160', 'time': '1.6716'}
# Quantizing self_attn.o_proj in layer 17 of 32:  50%|█████     | 16/32 [14:36<14:21, 53.87s/it]INFO - {'layer': 17, 'module': 'self_attn.o_proj', 'avg_loss': '0.0086', 'time': '1.6825'}
# Quantizing mlp.up_proj in layer 17 of 32:  50%|█████     | 16/32 [14:43<14:21, 53.87s/it]     INFO - {'layer': 17, 'module': 'mlp.up_proj', 'avg_loss': '9.3354', 'time': '1.7987'}
# Quantizing mlp.gate_proj in layer 17 of 32:  50%|█████     | 16/32 [14:44<14:21, 53.87s/it]INFO - {'layer': 17, 'module': 'mlp.gate_proj', 'avg_loss': '11.1826', 'time': '1.7423'}
# Quantizing mlp.down_proj in layer 17 of 32:  50%|█████     | 16/32 [15:05<14:21, 53.87s/it]INFO - {'layer': 17, 'module': 'mlp.down_proj', 'avg_loss': '0.0274', 'time': '7.0780'}
# Quantizing self_attn.k_proj in layer 18 of 32:  53%|█████▎    | 17/32 [15:21<13:28, 53.87s/it]INFO - {'layer': 18, 'module': 'self_attn.k_proj', 'avg_loss': '2.1772', 'time': '1.6756'}
# Quantizing self_attn.v_proj in layer 18 of 32:  53%|█████▎    | 17/32 [15:23<13:28, 53.87s/it]INFO - {'layer': 18, 'module': 'self_attn.v_proj', 'avg_loss': '0.7861', 'time': '1.6420'}
# Quantizing self_attn.q_proj in layer 18 of 32:  53%|█████▎    | 17/32 [15:24<13:28, 53.87s/it]INFO - {'layer': 18, 'module': 'self_attn.q_proj', 'avg_loss': '5.2246', 'time': '1.6596'}
# Quantizing self_attn.o_proj in layer 18 of 32:  53%|█████▎    | 17/32 [15:30<13:28, 53.87s/it]INFO - {'layer': 18, 'module': 'self_attn.o_proj', 'avg_loss': '0.0088', 'time': '1.6661'}
# Quantizing mlp.up_proj in layer 18 of 32:  53%|█████▎    | 17/32 [15:37<13:28, 53.87s/it]     INFO - {'layer': 18, 'module': 'mlp.up_proj', 'avg_loss': '11.0285', 'time': '1.7645'}
# Quantizing mlp.gate_proj in layer 18 of 32:  53%|█████▎    | 17/32 [15:38<13:28, 53.87s/it]INFO - {'layer': 18, 'module': 'mlp.gate_proj', 'avg_loss': '13.1948', 'time': '1.7399'}
# Quantizing mlp.down_proj in layer 18 of 32:  53%|█████▎    | 17/32 [15:59<13:28, 53.87s/it]INFO - {'layer': 18, 'module': 'mlp.down_proj', 'avg_loss': '0.0368', 'time': '7.0772'}
# Quantizing self_attn.k_proj in layer 19 of 32:  56%|█████▋    | 18/32 [16:15<12:34, 53.92s/it]INFO - {'layer': 19, 'module': 'self_attn.k_proj', 'avg_loss': '2.6958', 'time': '1.6484'}
# Quantizing self_attn.v_proj in layer 19 of 32:  56%|█████▋    | 18/32 [16:17<12:34, 53.92s/it]INFO - {'layer': 19, 'module': 'self_attn.v_proj', 'avg_loss': '0.9767', 'time': '1.6371'}
# Quantizing self_attn.q_proj in layer 19 of 32:  56%|█████▋    | 18/32 [16:18<12:34, 53.92s/it]INFO - {'layer': 19, 'module': 'self_attn.q_proj', 'avg_loss': '6.5157', 'time': '1.6681'}
# Quantizing self_attn.o_proj in layer 19 of 32:  56%|█████▋    | 18/32 [16:24<12:34, 53.92s/it]INFO - {'layer': 19, 'module': 'self_attn.o_proj', 'avg_loss': '0.0097', 'time': '1.6649'}
# Quantizing mlp.up_proj in layer 19 of 32:  56%|█████▋    | 18/32 [16:30<12:34, 53.92s/it]     INFO - {'layer': 19, 'module': 'mlp.up_proj', 'avg_loss': '12.4758', 'time': '1.7617'}
# Quantizing mlp.gate_proj in layer 19 of 32:  56%|█████▋    | 18/32 [16:32<12:34, 53.92s/it]INFO - {'layer': 19, 'module': 'mlp.gate_proj', 'avg_loss': '15.0539', 'time': '1.7736'}
# Quantizing mlp.down_proj in layer 19 of 32:  56%|█████▋    | 18/32 [16:52<12:34, 53.92s/it]INFO - {'layer': 19, 'module': 'mlp.down_proj', 'avg_loss': '0.0504', 'time': '7.0446'}
# Quantizing self_attn.k_proj in layer 20 of 32:  59%|█████▉    | 19/32 [17:09<11:40, 53.88s/it]INFO - {'layer': 20, 'module': 'self_attn.k_proj', 'avg_loss': '2.8315', 'time': '1.6625'}
# Quantizing self_attn.v_proj in layer 20 of 32:  59%|█████▉    | 19/32 [17:10<11:40, 53.88s/it]INFO - {'layer': 20, 'module': 'self_attn.v_proj', 'avg_loss': '1.1434', 'time': '1.6389'}
# Quantizing self_attn.q_proj in layer 20 of 32:  59%|█████▉    | 19/32 [17:12<11:40, 53.88s/it]INFO - {'layer': 20, 'module': 'self_attn.q_proj', 'avg_loss': '6.4329', 'time': '1.6720'}
# Quantizing self_attn.o_proj in layer 20 of 32:  59%|█████▉    | 19/32 [17:18<11:40, 53.88s/it]INFO - {'layer': 20, 'module': 'self_attn.o_proj', 'avg_loss': '0.0117', 'time': '1.6795'}
# Quantizing mlp.up_proj in layer 20 of 32:  59%|█████▉    | 19/32 [17:24<11:40, 53.88s/it]     INFO - {'layer': 20, 'module': 'mlp.up_proj', 'avg_loss': '14.0282', 'time': '1.7696'}
# Quantizing mlp.gate_proj in layer 20 of 32:  59%|█████▉    | 19/32 [17:26<11:40, 53.88s/it]INFO - {'layer': 20, 'module': 'mlp.gate_proj', 'avg_loss': '17.3652', 'time': '1.7322'}
# Quantizing mlp.down_proj in layer 20 of 32:  59%|█████▉    | 19/32 [17:46<11:40, 53.88s/it]INFO - {'layer': 20, 'module': 'mlp.down_proj', 'avg_loss': '0.0661', 'time': '7.0513'}
# Quantizing self_attn.k_proj in layer 21 of 32:  62%|██████▎   | 20/32 [18:03<10:46, 53.86s/it]INFO - {'layer': 21, 'module': 'self_attn.k_proj', 'avg_loss': '3.0496', 'time': '1.6520'}
# Quantizing self_attn.v_proj in layer 21 of 32:  62%|██████▎   | 20/32 [18:04<10:46, 53.86s/it]INFO - {'layer': 21, 'module': 'self_attn.v_proj', 'avg_loss': '1.3365', 'time': '1.6393'}
# Quantizing self_attn.q_proj in layer 21 of 32:  62%|██████▎   | 20/32 [18:06<10:46, 53.86s/it]INFO - {'layer': 21, 'module': 'self_attn.q_proj', 'avg_loss': '6.9566', 'time': '1.6615'}
# Quantizing self_attn.o_proj in layer 21 of 32:  62%|██████▎   | 20/32 [18:11<10:46, 53.86s/it]INFO - {'layer': 21, 'module': 'self_attn.o_proj', 'avg_loss': '0.0122', 'time': '1.6781'}
# Quantizing mlp.up_proj in layer 21 of 32:  62%|██████▎   | 20/32 [18:18<10:46, 53.86s/it]     INFO - {'layer': 21, 'module': 'mlp.up_proj', 'avg_loss': '15.9965', 'time': '1.7736'}
# Quantizing mlp.gate_proj in layer 21 of 32:  62%|██████▎   | 20/32 [18:20<10:46, 53.86s/it]INFO - {'layer': 21, 'module': 'mlp.gate_proj', 'avg_loss': '20.4650', 'time': '1.7398'}
# Quantizing mlp.down_proj in layer 21 of 32:  62%|██████▎   | 20/32 [18:40<10:46, 53.86s/it]INFO - {'layer': 21, 'module': 'mlp.down_proj', 'avg_loss': '0.0712', 'time': '7.0572'}
# Quantizing self_attn.k_proj in layer 22 of 32:  66%|██████▌   | 21/32 [18:56<09:52, 53.85s/it]INFO - {'layer': 22, 'module': 'self_attn.k_proj', 'avg_loss': '3.0318', 'time': '1.6564'}
# Quantizing self_attn.v_proj in layer 22 of 32:  66%|██████▌   | 21/32 [18:58<09:52, 53.85s/it]INFO - {'layer': 22, 'module': 'self_attn.v_proj', 'avg_loss': '1.7131', 'time': '1.6535'}
# Quantizing self_attn.q_proj in layer 22 of 32:  66%|██████▌   | 21/32 [19:00<09:52, 53.85s/it]INFO - {'layer': 22, 'module': 'self_attn.q_proj', 'avg_loss': '7.0635', 'time': '1.6615'}
# Quantizing self_attn.o_proj in layer 22 of 32:  66%|██████▌   | 21/32 [19:05<09:52, 53.85s/it]INFO - {'layer': 22, 'module': 'self_attn.o_proj', 'avg_loss': '0.0111', 'time': '1.6836'}
# Quantizing mlp.up_proj in layer 22 of 32:  66%|██████▌   | 21/32 [19:12<09:52, 53.85s/it]     INFO - {'layer': 22, 'module': 'mlp.up_proj', 'avg_loss': '18.0826', 'time': '1.7706'}
# Quantizing mlp.gate_proj in layer 22 of 32:  66%|██████▌   | 21/32 [19:14<09:52, 53.85s/it]INFO - {'layer': 22, 'module': 'mlp.gate_proj', 'avg_loss': '24.8036', 'time': '1.7563'}
# Quantizing mlp.down_proj in layer 22 of 32:  66%|██████▌   | 21/32 [19:34<09:52, 53.85s/it]INFO - {'layer': 22, 'module': 'mlp.down_proj', 'avg_loss': '0.0737', 'time': '7.0811'}
# Quantizing self_attn.k_proj in layer 23 of 32:  69%|██████▉   | 22/32 [19:50<08:58, 53.86s/it]INFO - {'layer': 23, 'module': 'self_attn.k_proj', 'avg_loss': '2.9429', 'time': '1.6566'}
# Quantizing self_attn.v_proj in layer 23 of 32:  69%|██████▉   | 22/32 [19:52<08:58, 53.86s/it]INFO - {'layer': 23, 'module': 'self_attn.v_proj', 'avg_loss': '2.4984', 'time': '1.6414'}
# Quantizing self_attn.q_proj in layer 23 of 32:  69%|██████▉   | 22/32 [19:54<08:58, 53.86s/it]INFO - {'layer': 23, 'module': 'self_attn.q_proj', 'avg_loss': '6.9927', 'time': '1.6599'}
# Quantizing self_attn.o_proj in layer 23 of 32:  69%|██████▉   | 22/32 [19:59<08:58, 53.86s/it]INFO - {'layer': 23, 'module': 'self_attn.o_proj', 'avg_loss': '0.0093', 'time': '1.6903'}
# Quantizing mlp.up_proj in layer 23 of 32:  69%|██████▉   | 22/32 [20:06<08:58, 53.86s/it]     INFO - {'layer': 23, 'module': 'mlp.up_proj', 'avg_loss': '19.6343', 'time': '1.7708'}
# Quantizing mlp.gate_proj in layer 23 of 32:  69%|██████▉   | 22/32 [20:08<08:58, 53.86s/it]INFO - {'layer': 23, 'module': 'mlp.gate_proj', 'avg_loss': '26.6527', 'time': '1.7412'}
# Quantizing mlp.down_proj in layer 23 of 32:  69%|██████▉   | 22/32 [20:28<08:58, 53.86s/it]INFO - {'layer': 23, 'module': 'mlp.down_proj', 'avg_loss': '0.0793', 'time': '7.0547'}
# Quantizing self_attn.k_proj in layer 24 of 32:  72%|███████▏  | 23/32 [20:44<08:04, 53.86s/it]INFO - {'layer': 24, 'module': 'self_attn.k_proj', 'avg_loss': '2.8957', 'time': '1.6629'}
# Quantizing self_attn.v_proj in layer 24 of 32:  72%|███████▏  | 23/32 [20:46<08:04, 53.86s/it]INFO - {'layer': 24, 'module': 'self_attn.v_proj', 'avg_loss': '2.3555', 'time': '1.6494'}
# Quantizing self_attn.q_proj in layer 24 of 32:  72%|███████▏  | 23/32 [20:48<08:04, 53.86s/it]INFO - {'layer': 24, 'module': 'self_attn.q_proj', 'avg_loss': '7.2192', 'time': '1.6638'}
# Quantizing self_attn.o_proj in layer 24 of 32:  72%|███████▏  | 23/32 [20:53<08:04, 53.86s/it]INFO - {'layer': 24, 'module': 'self_attn.o_proj', 'avg_loss': '0.0108', 'time': '1.6882'}
# Quantizing mlp.up_proj in layer 24 of 32:  72%|███████▏  | 23/32 [21:00<08:04, 53.86s/it]     INFO - {'layer': 24, 'module': 'mlp.up_proj', 'avg_loss': '21.5094', 'time': '1.8098'}
# Quantizing mlp.gate_proj in layer 24 of 32:  72%|███████▏  | 23/32 [21:02<08:04, 53.86s/it]INFO - {'layer': 24, 'module': 'mlp.gate_proj', 'avg_loss': '29.3943', 'time': '1.7495'}
# Quantizing mlp.down_proj in layer 24 of 32:  72%|███████▏  | 23/32 [21:22<08:04, 53.86s/it]INFO - {'layer': 24, 'module': 'mlp.down_proj', 'avg_loss': '0.0891', 'time': '7.1584'}
# Quantizing self_attn.k_proj in layer 25 of 32:  75%|███████▌  | 24/32 [21:38<07:11, 53.91s/it]INFO - {'layer': 25, 'module': 'self_attn.k_proj', 'avg_loss': '3.4488', 'time': '1.6596'}
# Quantizing self_attn.v_proj in layer 25 of 32:  75%|███████▌  | 24/32 [21:40<07:11, 53.91s/it]INFO - {'layer': 25, 'module': 'self_attn.v_proj', 'avg_loss': '2.2153', 'time': '1.6376'}
# Quantizing self_attn.q_proj in layer 25 of 32:  75%|███████▌  | 24/32 [21:42<07:11, 53.91s/it]INFO - {'layer': 25, 'module': 'self_attn.q_proj', 'avg_loss': '8.4052', 'time': '1.6666'}
# Quantizing self_attn.o_proj in layer 25 of 32:  75%|███████▌  | 24/32 [21:47<07:11, 53.91s/it]INFO - {'layer': 25, 'module': 'self_attn.o_proj', 'avg_loss': '0.0099', 'time': '1.7068'}
# Quantizing mlp.up_proj in layer 25 of 32:  75%|███████▌  | 24/32 [21:54<07:11, 53.91s/it]     INFO - {'layer': 25, 'module': 'mlp.up_proj', 'avg_loss': '23.6883', 'time': '1.7778'}
# Quantizing mlp.gate_proj in layer 25 of 32:  75%|███████▌  | 24/32 [21:56<07:11, 53.91s/it]INFO - {'layer': 25, 'module': 'mlp.gate_proj', 'avg_loss': '32.9768', 'time': '1.7422'}
# Quantizing mlp.down_proj in layer 25 of 32:  75%|███████▌  | 24/32 [22:16<07:11, 53.91s/it]INFO - {'layer': 25, 'module': 'mlp.down_proj', 'avg_loss': '0.0949', 'time': '7.0699'}
# Quantizing self_attn.k_proj in layer 26 of 32:  78%|███████▊  | 25/32 [22:32<06:17, 53.93s/it]INFO - {'layer': 26, 'module': 'self_attn.k_proj', 'avg_loss': '3.3439', 'time': '1.6614'}
# Quantizing self_attn.v_proj in layer 26 of 32:  78%|███████▊  | 25/32 [22:34<06:17, 53.93s/it]INFO - {'layer': 26, 'module': 'self_attn.v_proj', 'avg_loss': '2.9910', 'time': '1.6558'}
# Quantizing self_attn.q_proj in layer 26 of 32:  78%|███████▊  | 25/32 [22:36<06:17, 53.93s/it]INFO - {'layer': 26, 'module': 'self_attn.q_proj', 'avg_loss': '8.4432', 'time': '1.6837'}
# Quantizing self_attn.o_proj in layer 26 of 32:  78%|███████▊  | 25/32 [22:41<06:17, 53.93s/it]INFO - {'layer': 26, 'module': 'self_attn.o_proj', 'avg_loss': '0.0117', 'time': '1.6922'}
# Quantizing mlp.up_proj in layer 26 of 32:  78%|███████▊  | 25/32 [22:48<06:17, 53.93s/it]     INFO - {'layer': 26, 'module': 'mlp.up_proj', 'avg_loss': '25.7061', 'time': '1.7929'}
# Quantizing mlp.gate_proj in layer 26 of 32:  78%|███████▊  | 25/32 [22:50<06:17, 53.93s/it]INFO - {'layer': 26, 'module': 'mlp.gate_proj', 'avg_loss': '35.3916', 'time': '1.7454'}
# Quantizing mlp.down_proj in layer 26 of 32:  78%|███████▊  | 25/32 [23:10<06:17, 53.93s/it]INFO - {'layer': 26, 'module': 'mlp.down_proj', 'avg_loss': '0.1068', 'time': '7.1545'}
# Quantizing self_attn.k_proj in layer 27 of 32:  81%|████████▏ | 26/32 [23:26<05:23, 53.96s/it]INFO - {'layer': 27, 'module': 'self_attn.k_proj', 'avg_loss': '3.1029', 'time': '1.6645'}
# Quantizing self_attn.v_proj in layer 27 of 32:  81%|████████▏ | 26/32 [23:28<05:23, 53.96s/it]INFO - {'layer': 27, 'module': 'self_attn.v_proj', 'avg_loss': '2.5586', 'time': '1.6513'}
# Quantizing self_attn.q_proj in layer 27 of 32:  81%|████████▏ | 26/32 [23:30<05:23, 53.96s/it]INFO - {'layer': 27, 'module': 'self_attn.q_proj', 'avg_loss': '7.9276', 'time': '1.6635'}
# Quantizing self_attn.o_proj in layer 27 of 32:  81%|████████▏ | 26/32 [23:35<05:23, 53.96s/it]INFO - {'layer': 27, 'module': 'self_attn.o_proj', 'avg_loss': '0.0133', 'time': '1.6864'}
# Quantizing mlp.up_proj in layer 27 of 32:  81%|████████▏ | 26/32 [23:42<05:23, 53.96s/it]     INFO - {'layer': 27, 'module': 'mlp.up_proj', 'avg_loss': '27.2878', 'time': '1.7748'}
# Quantizing mlp.gate_proj in layer 27 of 32:  81%|████████▏ | 26/32 [23:44<05:23, 53.96s/it]INFO - {'layer': 27, 'module': 'mlp.gate_proj', 'avg_loss': '36.4132', 'time': '1.7473'}
# Quantizing mlp.down_proj in layer 27 of 32:  81%|████████▏ | 26/32 [24:04<05:23, 53.96s/it]INFO - {'layer': 27, 'module': 'mlp.down_proj', 'avg_loss': '0.1210', 'time': '7.0861'}
# Quantizing self_attn.k_proj in layer 28 of 32:  84%|████████▍ | 27/32 [24:20<04:30, 54.00s/it]INFO - {'layer': 28, 'module': 'self_attn.k_proj', 'avg_loss': '2.8875', 'time': '1.6506'}
# Quantizing self_attn.v_proj in layer 28 of 32:  84%|████████▍ | 27/32 [24:22<04:30, 54.00s/it]INFO - {'layer': 28, 'module': 'self_attn.v_proj', 'avg_loss': '3.1749', 'time': '1.6460'}
# Quantizing self_attn.q_proj in layer 28 of 32:  84%|████████▍ | 27/32 [24:24<04:30, 54.00s/it]INFO - {'layer': 28, 'module': 'self_attn.q_proj', 'avg_loss': '7.9627', 'time': '1.6683'}
# Quantizing self_attn.o_proj in layer 28 of 32:  84%|████████▍ | 27/32 [24:29<04:30, 54.00s/it]INFO - {'layer': 28, 'module': 'self_attn.o_proj', 'avg_loss': '0.0156', 'time': '1.6798'}
# Quantizing mlp.up_proj in layer 28 of 32:  84%|████████▍ | 27/32 [24:36<04:30, 54.00s/it]     INFO - {'layer': 28, 'module': 'mlp.up_proj', 'avg_loss': '29.1304', 'time': '1.7677'}
# Quantizing mlp.gate_proj in layer 28 of 32:  84%|████████▍ | 27/32 [24:38<04:30, 54.00s/it]INFO - {'layer': 28, 'module': 'mlp.gate_proj', 'avg_loss': '38.4318', 'time': '1.7693'}
# Quantizing mlp.down_proj in layer 28 of 32:  84%|████████▍ | 27/32 [24:58<04:30, 54.00s/it]INFO - {'layer': 28, 'module': 'mlp.down_proj', 'avg_loss': '0.1348', 'time': '7.0835'}
# Quantizing self_attn.k_proj in layer 29 of 32:  88%|████████▊ | 28/32 [25:14<03:35, 53.97s/it]INFO - {'layer': 29, 'module': 'self_attn.k_proj', 'avg_loss': '2.9280', 'time': '1.6606'}
# Quantizing self_attn.v_proj in layer 29 of 32:  88%|████████▊ | 28/32 [25:16<03:35, 53.97s/it]INFO - {'layer': 29, 'module': 'self_attn.v_proj', 'avg_loss': '2.9377', 'time': '1.6336'}
# Quantizing self_attn.q_proj in layer 29 of 32:  88%|████████▊ | 28/32 [25:18<03:35, 53.97s/it]INFO - {'layer': 29, 'module': 'self_attn.q_proj', 'avg_loss': '7.6680', 'time': '1.6591'}
# Quantizing self_attn.o_proj in layer 29 of 32:  88%|████████▊ | 28/32 [25:23<03:35, 53.97s/it]INFO - {'layer': 29, 'module': 'self_attn.o_proj', 'avg_loss': '0.0239', 'time': '1.6729'}
# Quantizing mlp.up_proj in layer 29 of 32:  88%|████████▊ | 28/32 [25:30<03:35, 53.97s/it]     INFO - {'layer': 29, 'module': 'mlp.up_proj', 'avg_loss': '31.1501', 'time': '1.7681'}
# Quantizing mlp.gate_proj in layer 29 of 32:  88%|████████▊ | 28/32 [25:31<03:35, 53.97s/it]INFO - {'layer': 29, 'module': 'mlp.gate_proj', 'avg_loss': '39.7813', 'time': '1.7415'}
# Quantizing mlp.down_proj in layer 29 of 32:  88%|████████▊ | 28/32 [25:52<03:35, 53.97s/it]INFO - {'layer': 29, 'module': 'mlp.down_proj', 'avg_loss': '0.1659', 'time': '7.1183'}
# Quantizing self_attn.k_proj in layer 30 of 32:  91%|█████████ | 29/32 [26:08<02:41, 53.94s/it]INFO - {'layer': 30, 'module': 'self_attn.k_proj', 'avg_loss': '2.6805', 'time': '1.6538'}
# Quantizing self_attn.v_proj in layer 30 of 32:  91%|█████████ | 29/32 [26:10<02:41, 53.94s/it]INFO - {'layer': 30, 'module': 'self_attn.v_proj', 'avg_loss': '4.1536', 'time': '1.6342'}
# Quantizing self_attn.q_proj in layer 30 of 32:  91%|█████████ | 29/32 [26:11<02:41, 53.94s/it]INFO - {'layer': 30, 'module': 'self_attn.q_proj', 'avg_loss': '8.3449', 'time': '1.6603'}
# Quantizing self_attn.o_proj in layer 30 of 32:  91%|█████████ | 29/32 [26:17<02:41, 53.94s/it]INFO - {'layer': 30, 'module': 'self_attn.o_proj', 'avg_loss': '0.0446', 'time': '1.6806'}
# Quantizing mlp.up_proj in layer 30 of 32:  91%|█████████ | 29/32 [26:24<02:41, 53.94s/it]     INFO - {'layer': 30, 'module': 'mlp.up_proj', 'avg_loss': '30.5539', 'time': '1.7774'}
# Quantizing mlp.gate_proj in layer 30 of 32:  91%|█████████ | 29/32 [26:25<02:41, 53.94s/it]INFO - {'layer': 30, 'module': 'mlp.gate_proj', 'avg_loss': '37.4908', 'time': '1.7597'}
# Quantizing mlp.down_proj in layer 30 of 32:  91%|█████████ | 29/32 [26:46<02:41, 53.94s/it]INFO - {'layer': 30, 'module': 'mlp.down_proj', 'avg_loss': '0.1960', 'time': '7.0667'}
# Quantizing self_attn.k_proj in layer 31 of 32:  94%|█████████▍| 30/32 [27:02<01:47, 53.93s/it]INFO - {'layer': 31, 'module': 'self_attn.k_proj', 'avg_loss': '2.7441', 'time': '1.6566'}
# Quantizing self_attn.v_proj in layer 31 of 32:  94%|█████████▍| 30/32 [27:04<01:47, 53.93s/it]INFO - {'layer': 31, 'module': 'self_attn.v_proj', 'avg_loss': '3.9838', 'time': '1.6697'}
# Quantizing self_attn.q_proj in layer 31 of 32:  94%|█████████▍| 30/32 [27:05<01:47, 53.93s/it]INFO - {'layer': 31, 'module': 'self_attn.q_proj', 'avg_loss': '8.0915', 'time': '1.6908'}
# Quantizing self_attn.o_proj in layer 31 of 32:  94%|█████████▍| 30/32 [27:11<01:47, 53.93s/it]INFO - {'layer': 31, 'module': 'self_attn.o_proj', 'avg_loss': '0.0481', 'time': '1.6693'}
# Quantizing mlp.up_proj in layer 31 of 32:  94%|█████████▍| 30/32 [27:18<01:47, 53.93s/it]     INFO - {'layer': 31, 'module': 'mlp.up_proj', 'avg_loss': '30.8899', 'time': '1.7754'}
# Quantizing mlp.gate_proj in layer 31 of 32:  94%|█████████▍| 30/32 [27:19<01:47, 53.93s/it]INFO - {'layer': 31, 'module': 'mlp.gate_proj', 'avg_loss': '37.2777', 'time': '1.7588'}
# Quantizing mlp.down_proj in layer 31 of 32:  94%|█████████▍| 30/32 [27:40<01:47, 53.93s/it]INFO - {'layer': 31, 'module': 'mlp.down_proj', 'avg_loss': '0.2454', 'time': '7.0937'}
# Quantizing self_attn.k_proj in layer 32 of 32:  97%|█████████▋| 31/32 [27:56<00:53, 53.94s/it]INFO - {'layer': 32, 'module': 'self_attn.k_proj', 'avg_loss': '2.4696', 'time': '1.6567'}
# Quantizing self_attn.v_proj in layer 32 of 32:  97%|█████████▋| 31/32 [27:58<00:53, 53.94s/it]INFO - {'layer': 32, 'module': 'self_attn.v_proj', 'avg_loss': '3.9814', 'time': '1.6363'}
# Quantizing self_attn.q_proj in layer 32 of 32:  97%|█████████▋| 31/32 [27:59<00:53, 53.94s/it]INFO - {'layer': 32, 'module': 'self_attn.q_proj', 'avg_loss': '7.4299', 'time': '1.6620'}
# Quantizing self_attn.o_proj in layer 32 of 32:  97%|█████████▋| 31/32 [28:05<00:53, 53.94s/it]INFO - {'layer': 32, 'module': 'self_attn.o_proj', 'avg_loss': '0.0690', 'time': '1.6923'}
# Quantizing mlp.up_proj in layer 32 of 32:  97%|█████████▋| 31/32 [28:12<00:53, 53.94s/it]     INFO - {'layer': 32, 'module': 'mlp.up_proj', 'avg_loss': '27.0282', 'time': '1.7696'}
# Quantizing mlp.gate_proj in layer 32 of 32:  97%|█████████▋| 31/32 [28:13<00:53, 53.94s/it]INFO - {'layer': 32, 'module': 'mlp.gate_proj', 'avg_loss': '33.8723', 'time': '1.7469'}
# Quantizing mlp.down_proj in layer 32 of 32:  97%|█████████▋| 31/32 [28:34<00:53, 53.94s/it]INFO - {'layer': 32, 'module': 'mlp.down_proj', 'avg_loss': '0.3929', 'time': '7.0728'}
# Quantizing mlp.down_proj in layer 32 of 32: 100%|██████████| 32/32 [28:43<00:00, 53.87s/it]
# INFO - Quantization summary:
# [{'layer': 1, 'module': 'self_attn.k_proj', 'avg_loss': '0.0241', 'time': '1.6384'}, {'layer': 1, 'module': 'self_attn.v_proj', 'avg_loss': '0.0011', 'time': '1.6030'}, {'layer': 1, 'module': 'self_attn.q_proj', 'avg_loss': '0.0933', 'time': '1.6508'}, {'layer': 1, 'module': 'self_attn.o_proj', 'avg_loss': '0.0000', 'time': '1.6612'}, {'layer': 1, 'module': 'mlp.up_proj', 'avg_loss': '0.0931', 'time': '1.8252'}, {'layer': 1, 'module': 'mlp.gate_proj', 'avg_loss': '0.1032', 'time': '1.7496'}, {'layer': 1, 'module': 'mlp.down_proj', 'avg_loss': '0.0001', 'time': '7.0378'}, {'layer': 2, 'module': 'self_attn.k_proj', 'avg_loss': '0.0859', 'time': '1.7096'}, {'layer': 2, 'module': 'self_attn.v_proj', 'avg_loss': '0.0092', 'time': '1.6594'}, {'layer': 2, 'module': 'self_attn.q_proj', 'avg_loss': '0.1904', 'time': '1.6806'}, {'layer': 2, 'module': 'self_attn.o_proj', 'avg_loss': '0.0001', 'time': '1.6936'}, {'layer': 2, 'module': 'mlp.up_proj', 'avg_loss': '0.3032', 'time': '1.7735'}, {'layer': 2, 'module': 'mlp.gate_proj', 'avg_loss': '0.3401', 'time': '1.7592'}, {'layer': 2, 'module': 'mlp.down_proj', 'avg_loss': '0.0597', 'time': '7.0816'}, {'layer': 3, 'module': 'self_attn.k_proj', 'avg_loss': '0.7164', 'time': '1.6581'}, {'layer': 3, 'module': 'self_attn.v_proj', 'avg_loss': '0.0660', 'time': '1.6376'}, {'layer': 3, 'module': 'self_attn.q_proj', 'avg_loss': '1.3538', 'time': '1.6700'}, {'layer': 3, 'module': 'self_attn.o_proj', 'avg_loss': '0.0001', 'time': '1.6813'}, {'layer': 3, 'module': 'mlp.up_proj', 'avg_loss': '0.7558', 'time': '1.7666'}, {'layer': 3, 'module': 'mlp.gate_proj', 'avg_loss': '0.8540', 'time': '1.7515'}, {'layer': 3, 'module': 'mlp.down_proj', 'avg_loss': '0.0003', 'time': '7.0831'}, {'layer': 4, 'module': 'self_attn.k_proj', 'avg_loss': '0.4896', 'time': '1.6663'}, {'layer': 4, 'module': 'self_attn.v_proj', 'avg_loss': '0.0743', 'time': '1.6931'}, {'layer': 4, 'module': 'self_attn.q_proj', 'avg_loss': '0.9487', 'time': '1.6856'}, {'layer': 4, 'module': 'self_attn.o_proj', 'avg_loss': '0.0002', 'time': '1.6871'}, {'layer': 4, 'module': 'mlp.up_proj', 'avg_loss': '1.1813', 'time': '1.7723'}, {'layer': 4, 'module': 'mlp.gate_proj', 'avg_loss': '1.3529', 'time': '1.7623'}, {'layer': 4, 'module': 'mlp.down_proj', 'avg_loss': '0.0006', 'time': '7.1264'}, {'layer': 5, 'module': 'self_attn.k_proj', 'avg_loss': '0.7491', 'time': '1.6673'}, {'layer': 5, 'module': 'self_attn.v_proj', 'avg_loss': '0.1344', 'time': '1.6446'}, {'layer': 5, 'module': 'self_attn.q_proj', 'avg_loss': '1.6472', 'time': '1.6620'}, {'layer': 5, 'module': 'self_attn.o_proj', 'avg_loss': '0.0002', 'time': '1.6904'}, {'layer': 5, 'module': 'mlp.up_proj', 'avg_loss': '1.5898', 'time': '1.7598'}, {'layer': 5, 'module': 'mlp.gate_proj', 'avg_loss': '1.9363', 'time': '1.7470'}, {'layer': 5, 'module': 'mlp.down_proj', 'avg_loss': '0.0011', 'time': '7.0637'}, {'layer': 6, 'module': 'self_attn.k_proj', 'avg_loss': '1.0580', 'time': '1.6672'}, {'layer': 6, 'module': 'self_attn.v_proj', 'avg_loss': '0.1945', 'time': '1.6453'}, {'layer': 6, 'module': 'self_attn.q_proj', 'avg_loss': '2.3354', 'time': '1.6734'}, {'layer': 6, 'module': 'self_attn.o_proj', 'avg_loss': '0.0006', 'time': '1.6832'}, {'layer': 6, 'module': 'mlp.up_proj', 'avg_loss': '2.1299', 'time': '1.7844'}, {'layer': 6, 'module': 'mlp.gate_proj', 'avg_loss': '2.7614', 'time': '1.7482'}, {'layer': 6, 'module': 'mlp.down_proj', 'avg_loss': '0.0020', 'time': '7.0896'}, {'layer': 7, 'module': 'self_attn.k_proj', 'avg_loss': '1.0519', 'time': '1.7210'}, {'layer': 7, 'module': 'self_attn.v_proj', 'avg_loss': '0.1847', 'time': '1.6362'}, {'layer': 7, 'module': 'self_attn.q_proj', 'avg_loss': '2.2436', 'time': '1.6745'}, {'layer': 7, 'module': 'self_attn.o_proj', 'avg_loss': '0.0006', 'time': '1.7041'}, {'layer': 7, 'module': 'mlp.up_proj', 'avg_loss': '2.6336', 'time': '1.7700'}, {'layer': 7, 'module': 'mlp.gate_proj', 'avg_loss': '3.3696', 'time': '1.7505'}, {'layer': 7, 'module': 'mlp.down_proj', ' ...
# INFO - {'layer': 1, 'module': 'self_attn.k_proj', 'avg_loss': '0.0241', 'time': '1.6384'}
# INFO - {'layer': 1, 'module': 'self_attn.v_proj', 'avg_loss': '0.0011', 'time': '1.6030'}
# INFO - {'layer': 1, 'module': 'self_attn.q_proj', 'avg_loss': '0.0933', 'time': '1.6508'}
# INFO - {'layer': 1, 'module': 'self_attn.o_proj', 'avg_loss': '0.0000', 'time': '1.6612'}
# INFO - {'layer': 1, 'module': 'mlp.up_proj', 'avg_loss': '0.0931', 'time': '1.8252'}
# INFO - {'layer': 1, 'module': 'mlp.gate_proj', 'avg_loss': '0.1032', 'time': '1.7496'}
# INFO - {'layer': 1, 'module': 'mlp.down_proj', 'avg_loss': '0.0001', 'time': '7.0378'}
# INFO - {'layer': 2, 'module': 'self_attn.k_proj', 'avg_loss': '0.0859', 'time': '1.7096'}
# INFO - {'layer': 2, 'module': 'self_attn.v_proj', 'avg_loss': '0.0092', 'time': '1.6594'}
# INFO - {'layer': 2, 'module': 'self_attn.q_proj', 'avg_loss': '0.1904', 'time': '1.6806'}
# INFO - {'layer': 2, 'module': 'self_attn.o_proj', 'avg_loss': '0.0001', 'time': '1.6936'}
# INFO - {'layer': 2, 'module': 'mlp.up_proj', 'avg_loss': '0.3032', 'time': '1.7735'}
# INFO - {'layer': 2, 'module': 'mlp.gate_proj', 'avg_loss': '0.3401', 'time': '1.7592'}
# INFO - {'layer': 2, 'module': 'mlp.down_proj', 'avg_loss': '0.0597', 'time': '7.0816'}
# INFO - {'layer': 3, 'module': 'self_attn.k_proj', 'avg_loss': '0.7164', 'time': '1.6581'}
# INFO - {'layer': 3, 'module': 'self_attn.v_proj', 'avg_loss': '0.0660', 'time': '1.6376'}
# INFO - {'layer': 3, 'module': 'self_attn.q_proj', 'avg_loss': '1.3538', 'time': '1.6700'}
# INFO - {'layer': 3, 'module': 'self_attn.o_proj', 'avg_loss': '0.0001', 'time': '1.6813'}
# INFO - {'layer': 3, 'module': 'mlp.up_proj', 'avg_loss': '0.7558', 'time': '1.7666'}
# INFO - {'layer': 3, 'module': 'mlp.gate_proj', 'avg_loss': '0.8540', 'time': '1.7515'}
# INFO - {'layer': 3, 'module': 'mlp.down_proj', 'avg_loss': '0.0003', 'time': '7.0831'}
# INFO - {'layer': 4, 'module': 'self_attn.k_proj', 'avg_loss': '0.4896', 'time': '1.6663'}
# INFO - {'layer': 4, 'module': 'self_attn.v_proj', 'avg_loss': '0.0743', 'time': '1.6931'}
# INFO - {'layer': 4, 'module': 'self_attn.q_proj', 'avg_loss': '0.9487', 'time': '1.6856'}
# INFO - {'layer': 4, 'module': 'self_attn.o_proj', 'avg_loss': '0.0002', 'time': '1.6871'}
# INFO - {'layer': 4, 'module': 'mlp.up_proj', 'avg_loss': '1.1813', 'time': '1.7723'}
# INFO - {'layer': 4, 'module': 'mlp.gate_proj', 'avg_loss': '1.3529', 'time': '1.7623'}
# INFO - {'layer': 4, 'module': 'mlp.down_proj', 'avg_loss': '0.0006', 'time': '7.1264'}
# INFO - {'layer': 5, 'module': 'self_attn.k_proj', 'avg_loss': '0.7491', 'time': '1.6673'}
# INFO - {'layer': 5, 'module': 'self_attn.v_proj', 'avg_loss': '0.1344', 'time': '1.6446'}
# INFO - {'layer': 5, 'module': 'self_attn.q_proj', 'avg_loss': '1.6472', 'time': '1.6620'}
# INFO - {'layer': 5, 'module': 'self_attn.o_proj', 'avg_loss': '0.0002', 'time': '1.6904'}
# ...
# INFO - {'layer': 9, 'module': 'self_attn.v_proj', 'avg_loss': '0.2350', 'time': '1.6359'}
# INFO - {'layer': 9, 'module': 'self_attn.q_proj', 'avg_loss': '2.5413', 'time': '1.6609'}
# INFO - {'layer': 9, 'module': 'self_attn.o_proj', 'avg_loss': '0.0013', 'time': '1.6756'}
# INFO - {'layer': 9, 'module': 'mlp.up_proj', 'avg_loss': '3.6303', 'time': '1.8260'}
# INFO - {'layer': 9, 'module': 'mlp.gate_proj', 'avg_loss': '4.6187', 'time': '1.7430'}
# INFO - {'layer': 9, 'module': 'mlp.down_proj', 'avg_loss': '0.0046', 'time': '7.0796'}
# INFO - {'layer': 10, 'module': 'self_attn.k_proj', 'avg_loss': '1.6795', 'time': '1.6592'}
# INFO - {'layer': 10, 'module': 'self_attn.v_proj', 'avg_loss': '0.2979', 'time': '1.6417'}
# INFO - {'layer': 10, 'module': 'self_attn.q_proj', 'avg_loss': '3.5786', 'time': '1.6734'}
# INFO - {'layer': 10, 'module': 'self_attn.o_proj', 'avg_loss': '0.0016', 'time': '1.6831'}
# INFO - {'layer': 10, 'module': 'mlp.up_proj', 'avg_loss': '3.9789', 'time': '1.7653'}
# INFO - {'layer': 10, 'module': 'mlp.gate_proj', 'avg_loss': '4.8817', 'time': '1.7489'}
# INFO - {'layer': 10, 'module': 'mlp.down_proj', 'avg_loss': '0.0057', 'time': '7.0931'}
# INFO - {'layer': 11, 'module': 'self_attn.k_proj', 'avg_loss': '1.4588', 'time': '1.6643'}
# INFO - {'layer': 11, 'module': 'self_attn.v_proj', 'avg_loss': '0.2510', 'time': '1.6512'}
# INFO - {'layer': 11, 'module': 'self_attn.q_proj', 'avg_loss': '3.1054', 'time': '1.6678'}
# INFO - {'layer': 11, 'module': 'self_attn.o_proj', 'avg_loss': '0.0021', 'time': '1.6863'}
# INFO - {'layer': 11, 'module': 'mlp.up_proj', 'avg_loss': '4.1272', 'time': '1.7652'}
# INFO - {'layer': 11, 'module': 'mlp.gate_proj', 'avg_loss': '4.9501', 'time': '1.7512'}
# INFO - {'layer': 11, 'module': 'mlp.down_proj', 'avg_loss': '0.0063', 'time': '7.0967'}
# INFO - {'layer': 12, 'module': 'self_attn.k_proj', 'avg_loss': '1.7348', 'time': '1.6646'}
# INFO - {'layer': 12, 'module': 'self_attn.v_proj', 'avg_loss': '0.3818', 'time': '1.6479'}
# INFO - {'layer': 12, 'module': 'self_attn.q_proj', 'avg_loss': '3.7540', 'time': '1.6787'}
# INFO - {'layer': 12, 'module': 'self_attn.o_proj', 'avg_loss': '0.0032', 'time': '1.6881'}
# INFO - {'layer': 12, 'module': 'mlp.up_proj', 'avg_loss': '4.5521', 'time': '1.7812'}
# INFO - {'layer': 12, 'module': 'mlp.gate_proj', 'avg_loss': '5.3604', 'time': '1.7474'}
# INFO - {'layer': 12, 'module': 'mlp.down_proj', 'avg_loss': '0.0074', 'time': '7.0762'}
# INFO - {'layer': 13, 'module': 'self_attn.k_proj', 'avg_loss': '2.1815', 'time': '1.6676'}
# INFO - {'layer': 13, 'module': 'self_attn.v_proj', 'avg_loss': '0.4272', 'time': '1.6654'}
# INFO - {'layer': 13, 'module': 'self_attn.q_proj', 'avg_loss': '4.7797', 'time': '1.6938'}
# INFO - {'layer': 13, 'module': 'self_attn.o_proj', 'avg_loss': '0.0036', 'time': '1.6809'}
# INFO - {'layer': 13, 'module': 'mlp.up_proj', 'avg_loss': '5.2774', 'time': '1.7791'}
# INFO - {'layer': 13, 'module': 'mlp.gate_proj', 'avg_loss': '6.0589', 'time': '1.7466'}
# INFO - {'layer': 13, 'module': 'mlp.down_proj', 'avg_loss': '0.0095', 'time': '7.1135'}
# INFO - {'layer': 14, 'module': 'self_attn.k_proj', 'avg_loss': '2.0238', 'time': '1.6578'}
# INFO - {'layer': 14, 'module': 'self_attn.v_proj', 'avg_loss': '0.4410', 'time': '1.6488'}
# INFO - {'layer': 14, 'module': 'self_attn.q_proj', 'avg_loss': '4.2040', 'time': '1.6649'}
# INFO - {'layer': 14, 'module': 'self_attn.o_proj', 'avg_loss': '0.0047', 'time': '1.6968'}
# INFO - {'layer': 14, 'module': 'mlp.up_proj', 'avg_loss': '6.0502', 'time': '1.7812'}
# INFO - {'layer': 14, 'module': 'mlp.gate_proj', 'avg_loss': '6.7315', 'time': '1.7494'}
# INFO - {'layer': 14, 'module': 'mlp.down_proj', 'avg_loss': '0.0117', 'time': '7.0666'}
# INFO - {'layer': 15, 'module': 'self_attn.k_proj', 'avg_loss': '2.0470', 'time': '1.6866'}
# INFO - {'layer': 15, 'module': 'self_attn.v_proj', 'avg_loss': '0.6789', 'time': '1.6353'}
# INFO - {'layer': 15, 'module': 'self_attn.q_proj', 'avg_loss': '4.7577', 'time': '1.6677'}
# INFO - {'layer': 15, 'module': 'self_attn.o_proj', 'avg_loss': '0.0065', 'time': '1.6777'}
# INFO - {'layer': 15, 'module': 'mlp.up_proj', 'avg_loss': '6.8091', 'time': '1.8100'}
# INFO - {'layer': 15, 'module': 'mlp.gate_proj', 'avg_loss': '7.5331', 'time': '1.7539'}
# INFO - {'layer': 15, 'module': 'mlp.down_proj', 'avg_loss': '0.0152', 'time': '7.1111'}
# INFO - {'layer': 16, 'module': 'self_attn.k_proj', 'avg_loss': '2.6365', 'time': '1.6579'}
# INFO - {'layer': 16, 'module': 'self_attn.v_proj', 'avg_loss': '0.8908', 'time': '1.6393'}
# INFO - {'layer': 16, 'module': 'self_attn.q_proj', 'avg_loss': '5.9490', 'time': '1.6615'}
# INFO - {'layer': 16, 'module': 'self_attn.o_proj', 'avg_loss': '0.0076', 'time': '1.6970'}
# INFO - {'layer': 16, 'module': 'mlp.up_proj', 'avg_loss': '7.8308', 'time': '1.7767'}
# INFO - {'layer': 16, 'module': 'mlp.gate_proj', 'avg_loss': '8.9347', 'time': '1.7387'}
# INFO - {'layer': 16, 'module': 'mlp.down_proj', 'avg_loss': '0.0199', 'time': '7.0743'}
# INFO - {'layer': 17, 'module': 'self_attn.k_proj', 'avg_loss': '2.6732', 'time': '1.6637'}
# INFO - {'layer': 17, 'module': 'self_attn.v_proj', 'avg_loss': '0.8127', 'time': '1.6456'}
# INFO - {'layer': 17, 'module': 'self_attn.q_proj', 'avg_loss': '5.8160', 'time': '1.6716'}
# INFO - {'layer': 17, 'module': 'self_attn.o_proj', 'avg_loss': '0.0086', 'time': '1.6825'}
# INFO - {'layer': 17, 'module': 'mlp.up_proj', 'avg_loss': '9.3354', 'time': '1.7987'}
# INFO - {'layer': 17, 'module': 'mlp.gate_proj', 'avg_loss': '11.1826', 'time': '1.7423'}
# INFO - {'layer': 17, 'module': 'mlp.down_proj', 'avg_loss': '0.0274', 'time': '7.0780'}
# INFO - {'layer': 18, 'module': 'self_attn.k_proj', 'avg_loss': '2.1772', 'time': '1.6756'}
# INFO - {'layer': 18, 'module': 'self_attn.v_proj', 'avg_loss': '0.7861', 'time': '1.6420'}
# INFO - {'layer': 18, 'module': 'self_attn.q_proj', 'avg_loss': '5.2246', 'time': '1.6596'}
# INFO - {'layer': 18, 'module': 'self_attn.o_proj', 'avg_loss': '0.0088', 'time': '1.6661'}
# INFO - {'layer': 18, 'module': 'mlp.up_proj', 'avg_loss': '11.0285', 'time': '1.7645'}
# INFO - {'layer': 18, 'module': 'mlp.gate_proj', 'avg_loss': '13.1948', 'time': '1.7399'}
# INFO - {'layer': 18, 'module': 'mlp.down_proj', 'avg_loss': '0.0368', 'time': '7.0772'}
# INFO - {'layer': 19, 'module': 'self_attn.k_proj', 'avg_loss': '2.6958', 'time': '1.6484'}
# INFO - {'layer': 19, 'module': 'self_attn.v_proj', 'avg_loss': '0.9767', 'time': '1.6371'}
# INFO - {'layer': 19, 'module': 'self_attn.q_proj', 'avg_loss': '6.5157', 'time': '1.6681'}
# INFO - {'layer': 19, 'module': 'self_attn.o_proj', 'avg_loss': '0.0097', 'time': '1.6649'}
# INFO - {'layer': 19, 'module': 'mlp.up_proj', 'avg_loss': '12.4758', 'time': '1.7617'}
# INFO - {'layer': 19, 'module': 'mlp.gate_proj', 'avg_loss': '15.0539', 'time': '1.7736'}
# INFO - {'layer': 19, 'module': 'mlp.down_proj', 'avg_loss': '0.0504', 'time': '7.0446'}
# INFO - {'layer': 20, 'module': 'self_attn.k_proj', 'avg_loss': '2.8315', 'time': '1.6625'}
# INFO - {'layer': 20, 'module': 'self_attn.v_proj', 'avg_loss': '1.1434', 'time': '1.6389'}
# INFO - {'layer': 20, 'module': 'self_attn.q_proj', 'avg_loss': '6.4329', 'time': '1.6720'}
# INFO - {'layer': 20, 'module': 'self_attn.o_proj', 'avg_loss': '0.0117', 'time': '1.6795'}
# INFO - {'layer': 20, 'module': 'mlp.up_proj', 'avg_loss': '14.0282', 'time': '1.7696'}
# INFO - {'layer': 20, 'module': 'mlp.gate_proj', 'avg_loss': '17.3652', 'time': '1.7322'}
# INFO - {'layer': 20, 'module': 'mlp.down_proj', 'avg_loss': '0.0661', 'time': '7.0513'}
# INFO - {'layer': 21, 'module': 'self_attn.k_proj', 'avg_loss': '3.0496', 'time': '1.6520'}
# INFO - {'layer': 21, 'module': 'self_attn.v_proj', 'avg_loss': '1.3365', 'time': '1.6393'}
# INFO - {'layer': 21, 'module': 'self_attn.q_proj', 'avg_loss': '6.9566', 'time': '1.6615'}
# INFO - {'layer': 21, 'module': 'self_attn.o_proj', 'avg_loss': '0.0122', 'time': '1.6781'}
# INFO - {'layer': 21, 'module': 'mlp.up_proj', 'avg_loss': '15.9965', 'time': '1.7736'}
# INFO - {'layer': 21, 'module': 'mlp.gate_proj', 'avg_loss': '20.4650', 'time': '1.7398'}
# INFO - {'layer': 21, 'module': 'mlp.down_proj', 'avg_loss': '0.0712', 'time': '7.0572'}
# INFO - {'layer': 22, 'module': 'self_attn.k_proj', 'avg_loss': '3.0318', 'time': '1.6564'}
# INFO - {'layer': 22, 'module': 'self_attn.v_proj', 'avg_loss': '1.7131', 'time': '1.6535'}
# INFO - {'layer': 22, 'module': 'self_attn.q_proj', 'avg_loss': '7.0635', 'time': '1.6615'}
# INFO - {'layer': 22, 'module': 'self_attn.o_proj', 'avg_loss': '0.0111', 'time': '1.6836'}
# INFO - {'layer': 22, 'module': 'mlp.up_proj', 'avg_loss': '18.0826', 'time': '1.7706'}
# INFO - {'layer': 22, 'module': 'mlp.gate_proj', 'avg_loss': '24.8036', 'time': '1.7563'}
# INFO - {'layer': 22, 'module': 'mlp.down_proj', 'avg_loss': '0.0737', 'time': '7.0811'}
# INFO - {'layer': 23, 'module': 'self_attn.k_proj', 'avg_loss': '2.9429', 'time': '1.6566'}
# INFO - {'layer': 23, 'module': 'self_attn.v_proj', 'avg_loss': '2.4984', 'time': '1.6414'}
# INFO - {'layer': 23, 'module': 'self_attn.q_proj', 'avg_loss': '6.9927', 'time': '1.6599'}
# INFO - {'layer': 23, 'module': 'self_attn.o_proj', 'avg_loss': '0.0093', 'time': '1.6903'}
# INFO - {'layer': 23, 'module': 'mlp.up_proj', 'avg_loss': '19.6343', 'time': '1.7708'}
# INFO - {'layer': 23, 'module': 'mlp.gate_proj', 'avg_loss': '26.6527', 'time': '1.7412'}
# INFO - {'layer': 23, 'module': 'mlp.down_proj', 'avg_loss': '0.0793', 'time': '7.0547'}
# INFO - {'layer': 24, 'module': 'self_attn.k_proj', 'avg_loss': '2.8957', 'time': '1.6629'}
# INFO - {'layer': 24, 'module': 'self_attn.v_proj', 'avg_loss': '2.3555', 'time': '1.6494'}
# INFO - {'layer': 24, 'module': 'self_attn.q_proj', 'avg_loss': '7.2192', 'time': '1.6638'}
# INFO - {'layer': 24, 'module': 'self_attn.o_proj', 'avg_loss': '0.0108', 'time': '1.6882'}
# INFO - {'layer': 24, 'module': 'mlp.up_proj', 'avg_loss': '21.5094', 'time': '1.8098'}
# INFO - {'layer': 24, 'module': 'mlp.gate_proj', 'avg_loss': '29.3943', 'time': '1.7495'}
# INFO - {'layer': 24, 'module': 'mlp.down_proj', 'avg_loss': '0.0891', 'time': '7.1584'}
# INFO - {'layer': 25, 'module': 'self_attn.k_proj', 'avg_loss': '3.4488', 'time': '1.6596'}
# INFO - {'layer': 25, 'module': 'self_attn.v_proj', 'avg_loss': '2.2153', 'time': '1.6376'}
# INFO - {'layer': 25, 'module': 'self_attn.q_proj', 'avg_loss': '8.4052', 'time': '1.6666'}
# INFO - {'layer': 25, 'module': 'self_attn.o_proj', 'avg_loss': '0.0099', 'time': '1.7068'}
# INFO - {'layer': 25, 'module': 'mlp.up_proj', 'avg_loss': '23.6883', 'time': '1.7778'}
# INFO - {'layer': 25, 'module': 'mlp.gate_proj', 'avg_loss': '32.9768', 'time': '1.7422'}
# INFO - {'layer': 25, 'module': 'mlp.down_proj', 'avg_loss': '0.0949', 'time': '7.0699'}
# INFO - {'layer': 26, 'module': 'self_attn.k_proj', 'avg_loss': '3.3439', 'time': '1.6614'}
# INFO - {'layer': 26, 'module': 'self_attn.v_proj', 'avg_loss': '2.9910', 'time': '1.6558'}
# INFO - {'layer': 26, 'module': 'self_attn.q_proj', 'avg_loss': '8.4432', 'time': '1.6837'}
# INFO - {'layer': 26, 'module': 'self_attn.o_proj', 'avg_loss': '0.0117', 'time': '1.6922'}
# INFO - {'layer': 26, 'module': 'mlp.up_proj', 'avg_loss': '25.7061', 'time': '1.7929'}
# INFO - {'layer': 26, 'module': 'mlp.gate_proj', 'avg_loss': '35.3916', 'time': '1.7454'}
# INFO - {'layer': 26, 'module': 'mlp.down_proj', 'avg_loss': '0.1068', 'time': '7.1545'}
# INFO - {'layer': 27, 'module': 'self_attn.k_proj', 'avg_loss': '3.1029', 'time': '1.6645'}
# INFO - {'layer': 27, 'module': 'self_attn.v_proj', 'avg_loss': '2.5586', 'time': '1.6513'}
# INFO - {'layer': 27, 'module': 'self_attn.q_proj', 'avg_loss': '7.9276', 'time': '1.6635'}
# INFO - {'layer': 27, 'module': 'self_attn.o_proj', 'avg_loss': '0.0133', 'time': '1.6864'}
# INFO - {'layer': 27, 'module': 'mlp.up_proj', 'avg_loss': '27.2878', 'time': '1.7748'}
# INFO - {'layer': 27, 'module': 'mlp.gate_proj', 'avg_loss': '36.4132', 'time': '1.7473'}
# INFO - {'layer': 27, 'module': 'mlp.down_proj', 'avg_loss': '0.1210', 'time': '7.0861'}
# INFO - {'layer': 28, 'module': 'self_attn.k_proj', 'avg_loss': '2.8875', 'time': '1.6506'}
# INFO - {'layer': 28, 'module': 'self_attn.v_proj', 'avg_loss': '3.1749', 'time': '1.6460'}
# INFO - {'layer': 28, 'module': 'self_attn.q_proj', 'avg_loss': '7.9627', 'time': '1.6683'}
# INFO - {'layer': 28, 'module': 'self_attn.o_proj', 'avg_loss': '0.0156', 'time': '1.6798'}
# INFO - {'layer': 28, 'module': 'mlp.up_proj', 'avg_loss': '29.1304', 'time': '1.7677'}
# INFO - {'layer': 28, 'module': 'mlp.gate_proj', 'avg_loss': '38.4318', 'time': '1.7693'}
# INFO - {'layer': 28, 'module': 'mlp.down_proj', 'avg_loss': '0.1348', 'time': '7.0835'}
# INFO - {'layer': 29, 'module': 'self_attn.k_proj', 'avg_loss': '2.9280', 'time': '1.6606'}
# INFO - {'layer': 29, 'module': 'self_attn.v_proj', 'avg_loss': '2.9377', 'time': '1.6336'}
# INFO - {'layer': 29, 'module': 'self_attn.q_proj', 'avg_loss': '7.6680', 'time': '1.6591'}
# INFO - {'layer': 29, 'module': 'self_attn.o_proj', 'avg_loss': '0.0239', 'time': '1.6729'}
# INFO - {'layer': 29, 'module': 'mlp.up_proj', 'avg_loss': '31.1501', 'time': '1.7681'}
# INFO - {'layer': 29, 'module': 'mlp.gate_proj', 'avg_loss': '39.7813', 'time': '1.7415'}
# INFO - {'layer': 29, 'module': 'mlp.down_proj', 'avg_loss': '0.1659', 'time': '7.1183'}
# INFO - {'layer': 30, 'module': 'self_attn.k_proj', 'avg_loss': '2.6805', 'time': '1.6538'}
# INFO - {'layer': 30, 'module': 'self_attn.v_proj', 'avg_loss': '4.1536', 'time': '1.6342'}
# INFO - {'layer': 30, 'module': 'self_attn.q_proj', 'avg_loss': '8.3449', 'time': '1.6603'}
# INFO - {'layer': 30, 'module': 'self_attn.o_proj', 'avg_loss': '0.0446', 'time': '1.6806'}
# INFO - {'layer': 30, 'module': 'mlp.up_proj', 'avg_loss': '30.5539', 'time': '1.7774'}
# INFO - {'layer': 30, 'module': 'mlp.gate_proj', 'avg_loss': '37.4908', 'time': '1.7597'}
# INFO - {'layer': 30, 'module': 'mlp.down_proj', 'avg_loss': '0.1960', 'time': '7.0667'}
# INFO - {'layer': 31, 'module': 'self_attn.k_proj', 'avg_loss': '2.7441', 'time': '1.6566'}
# INFO - {'layer': 31, 'module': 'self_attn.v_proj', 'avg_loss': '3.9838', 'time': '1.6697'}
# INFO - {'layer': 31, 'module': 'self_attn.q_proj', 'avg_loss': '8.0915', 'time': '1.6908'}
# INFO - {'layer': 31, 'module': 'self_attn.o_proj', 'avg_loss': '0.0481', 'time': '1.6693'}
# INFO - {'layer': 31, 'module': 'mlp.up_proj', 'avg_loss': '30.8899', 'time': '1.7754'}
# INFO - {'layer': 31, 'module': 'mlp.gate_proj', 'avg_loss': '37.2777', 'time': '1.7588'}
# INFO - {'layer': 31, 'module': 'mlp.down_proj', 'avg_loss': '0.2454', 'time': '7.0937'}
# INFO - {'layer': 32, 'module': 'self_attn.k_proj', 'avg_loss': '2.4696', 'time': '1.6567'}
# INFO - {'layer': 32, 'module': 'self_attn.v_proj', 'avg_loss': '3.9814', 'time': '1.6363'}
# INFO - {'layer': 32, 'module': 'self_attn.q_proj', 'avg_loss': '7.4299', 'time': '1.6620'}
# INFO - {'layer': 32, 'module': 'self_attn.o_proj', 'avg_loss': '0.0690', 'time': '1.6923'}
# INFO - {'layer': 32, 'module': 'mlp.up_proj', 'avg_loss': '27.0282', 'time': '1.7696'}
# INFO - {'layer': 32, 'module': 'mlp.gate_proj', 'avg_loss': '33.8723', 'time': '1.7469'}
# INFO - {'layer': 32, 'module': 'mlp.down_proj', 'avg_loss': '0.3929', 'time': '7.0728'}
# INFO - Packing model...
# INFO:gptqmodel.utils.model:Packing model...
# Packing model.layers.31.mlp.down_proj: 100%|██████████| 224/224 [05:51<00:00,  1.57s/it]
# INFO - Model packed.
# INFO:gptqmodel.utils.model:Model packed.
# Quantization complete!
# Saving quantized model...
# Note that `shard_checkpoint` is deprecated and will be removed in v4.44. We recommend you using split_torch_state_dict_into_shards from huggingface_hub library
# Saving quantized model complete!
# INFO - Compatibility: converting `checkpoint_format` from `gptq` to `gptq_v2`.
# Setting `pad_token_id` to `eos_token_id`:32000 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1259: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# <s> What is the capital of Jamaica?
#
# The capital of Jamaica is Kingston.

# %% [markdown]
# ### Upload Quantized Model to Hugging Face

# %% [markdown]
# Login to Hugging Face via PAT and then overwrite the existing Git repository with the newly quantized model's files.

# %%
from huggingface_hub import notebook_login

notebook_login()

from huggingface_hub import HfApi

api = HfApi()

api.upload_folder(
    folder_path="/content/NousResearch/Hermes-2-Pro-Mistral-7B-4bit-32g",
    repo_id="justinthelaw/Hermes-2-Pro-Mistral-7B-4bit-32g",
    repo_type="model",
)
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# model.safetensors:   0%|          | 0.00/4.57G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/justinthelaw/Hermes-2-Pro-Mistral-7B-4bit-32g/commit/50c326ebdbd58aae6140826646eaaf5a8d124fb3', commit_message='Upload folder using huggingface_hub', commit_description='', oid='50c326ebdbd58aae6140826646eaaf5a8d124fb3', pr_url=None, pr_revision=None, pr_num=None)
