# %% [markdown]
# ## GPTQModel Pipeline

# %% [markdown]
# ### Install GPTQModel

# %%
# clone GPTQModel repo
# !git clone --depth 1 --branch v0.9.9 https://github.com/ModelCloud/GPTQModel.git

# compile and install GPTQModel
# !cd GPTQModel && pip install --no-build-isolation .
# Out:
# Cloning into 'GPTQModel'...
# remote: Enumerating objects: 210, done.
# remote: Counting objects: 100% (210/210), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 210 (delta 35), reused 113 (delta 28), pack-reused 0
# Receiving objects: 100% (210/210), 200.96 KiB | 1.07 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Note: switching to '519fbe3ef02335c58e3aa8e9353f8346a8780b91'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# Processing /content/GPTQModel
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: accelerate>=0.31.0 in /usr/local/lib/python3.10/dist-packages (from gptqmodel==0.9.9+cu1222) (0.32.1)
# Collecting datasets>=2.20.0 (from gptqmodel==0.9.9+cu1222)
#   Using cached datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Collecting sentencepiece>=0.2.0 (from gptqmodel==0.9.9+cu1222)
#   Using cached sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.10/dist-packages (from gptqmodel==0.9.9+cu1222) (1.26.4)
# Collecting rouge>=1.0.1 (from gptqmodel==0.9.9+cu1222)
#   Using cached rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting gekko>=1.1.1 (from gptqmodel==0.9.9+cu1222)
#   Using cached gekko-1.2.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gptqmodel==0.9.9+cu1222) (2.3.1+cu121)
# Requirement already satisfied: triton>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gptqmodel==0.9.9+cu1222) (2.3.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from gptqmodel==0.9.9+cu1222) (0.4.3)
# Collecting transformers>=4.43.1 (from gptqmodel==0.9.9+cu1222)
#   Using cached transformers-4.43.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: tqdm>=4.66.4 in /usr/local/lib/python3.10/dist-packages (from gptqmodel==0.9.9+cu1222) (4.66.4)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from gptqmodel==0.9.9+cu1222) (3.5.0)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.10/dist-packages (from gptqmodel==0.9.9+cu1222) (24.1)
# Collecting ninja>=1.11.1.1 (from gptqmodel==0.9.9+cu1222)
#   Using cached ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Collecting protobuf>=4.25.3 (from gptqmodel==0.9.9+cu1222)
#   Using cached protobuf-5.27.2-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting intel_extension_for_transformers>=1.4.2 (from gptqmodel==0.9.9+cu1222)
#   Using cached intel_extension_for_transformers-1.4.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (26 kB)
# Collecting auto-round==0.2 (from gptqmodel==0.9.9+cu1222)
#   Using cached auto_round-0.2-py3-none-any.whl.metadata (17 kB)
# Collecting auto-gptq (from auto-round==0.2->gptqmodel==0.9.9+cu1222)
#   Using cached auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from auto-round==0.2->gptqmodel==0.9.9+cu1222) (9.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.31.0->gptqmodel==0.9.9+cu1222) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.31.0->gptqmodel==0.9.9+cu1222) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.31.0->gptqmodel==0.9.9+cu1222) (0.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (3.15.4)
# Collecting pyarrow>=15.0.0 (from datasets>=2.20.0->gptqmodel==0.9.9+cu1222)
#   Using cached pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.20.0->gptqmodel==0.9.9+cu1222)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (2.1.4)
# Collecting requests>=2.32.2 (from datasets>=2.20.0->gptqmodel==0.9.9+cu1222)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting xxhash (from datasets>=2.20.0->gptqmodel==0.9.9+cu1222)
#   Using cached xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets>=2.20.0->gptqmodel==0.9.9+cu1222)
#   Using cached multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets>=2.20.0->gptqmodel==0.9.9+cu1222)
#   Using cached fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (3.9.5)
# Collecting schema (from intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222)
#   Using cached schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Collecting neural-compressor (from intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222)
#   Using cached neural_compressor-2.6-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge>=1.0.1->gptqmodel==0.9.9+cu1222) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gptqmodel==0.9.9+cu1222) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gptqmodel==0.9.9+cu1222) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gptqmodel==0.9.9+cu1222) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gptqmodel==0.9.9+cu1222) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->gptqmodel==0.9.9+cu1222)
#   Using cached nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.43.1->gptqmodel==0.9.9+cu1222) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.43.1->gptqmodel==0.9.9+cu1222) (0.19.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (2024.7.4)
# Collecting peft>=0.5.0 (from auto-gptq->auto-round==0.2->gptqmodel==0.9.9+cu1222)
#   Using cached peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->gptqmodel==0.9.9+cu1222) (2.1.5)
# Collecting deprecated>=1.2.13 (from neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (4.10.0.84)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (9.4.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (3.10.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (1.3.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (2.0.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.20.0->gptqmodel==0.9.9+cu1222) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.0->gptqmodel==0.9.9+cu1222) (1.3.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (1.14.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (0.2.13)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (3.7.1)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel_extension_for_transformers>=1.4.2->gptqmodel==0.9.9+cu1222) (3.1.2)
# Using cached auto_round-0.2-py3-none-any.whl (66 kB)
# Using cached datasets-2.20.0-py3-none-any.whl (547 kB)
# Using cached gekko-1.2.1-py3-none-any.whl (13.2 MB)
# Using cached intel_extension_for_transformers-1.4.2-cp310-cp310-manylinux_2_28_x86_64.whl (45.3 MB)
# Using cached ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
# Using cached protobuf-5.27.2-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
# Using cached rouge-1.0.1-py3-none-any.whl (13 kB)
# Using cached sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached transformers-4.43.3-py3-none-any.whl (9.4 MB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached fsspec-2024.5.0-py3-none-any.whl (316 kB)
# Using cached pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
# Using cached multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Using cached neural_compressor-2.6-py3-none-any.whl (1.5 MB)
# Using cached schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Using cached xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached peft-0.12.0-py3-none-any.whl (296 kB)
# Using cached nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
# Building wheels for collected packages: gptqmodel
#   Building wheel for gptqmodel (setup.py) ... done
#   Created wheel for gptqmodel: filename=gptqmodel-0.9.9+cu1222-cp310-cp310-linux_x86_64.whl size=8892397 sha256=d92944ded4162683a831c48323e77a03dacd153bf2377a6de0db37bc203c5866
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p83tfpho/wheels/5f/53/9e/53df737a3ec324dade000b4b31e86fc0ed74b1385198b0dfba
# Successfully built gptqmodel
# WARNING: Error parsing dependencies of fsspec: [Errno 2] No such file or directory: '/usr/local/lib/python3.10/dist-packages/fsspec-2024.6.1.dist-info/METADATA'
# WARNING: Error parsing dependencies of protobuf: [Errno 2] No such file or directory: '/usr/local/lib/python3.10/dist-packages/protobuf-3.20.3.dist-info/METADATA'
# WARNING: Error parsing dependencies of pyarrow: [Errno 2] No such file or directory: '/usr/local/lib/python3.10/dist-packages/pyarrow-14.0.2.dist-info/METADATA'
# WARNING: Error parsing dependencies of requests: [Errno 2] No such file or directory: '/usr/local/lib/python3.10/dist-packages/requests-2.31.0.dist-info/METADATA'
# WARNING: Error parsing dependencies of sentencepiece: [Errno 2] No such file or directory: '/usr/local/lib/python3.10/dist-packages/sentencepiece-0.1.99.dist-info/METADATA'
# WARNING: Error parsing dependencies of transformers: [Errno 2] No such file or directory: '/usr/local/lib/python3.10/dist-packages/transformers-4.42.4.dist-info/METADATA'
# Installing collected packages: sentencepiece, schema, ninja, xxhash, rouge, requests, pyarrow, protobuf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, gekko, fsspec, dill, deprecated, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, transformers, neural-compressor, datasets, intel_extension_for_transformers, peft, auto-gptq, auto-round, gptqmodel
#   Attempting uninstall: sentencepiece
#     WARNING: No metadata found in /usr/local/lib/python3.10/dist-packages
#     Found existing installation: sentencepiece 0.1.99
#     Can't uninstall 'sentencepiece'. No files were found to uninstall.
#   Attempting uninstall: requests
#     WARNING: No metadata found in /usr/local/lib/python3.10/dist-packages
#     Found existing installation: requests 2.31.0
#     Can't uninstall 'requests'. No files were found to uninstall.
#   Attempting uninstall: pyarrow
#     WARNING: No metadata found in /usr/local/lib/python3.10/dist-packages
#     Found existing installation: pyarrow 14.0.2
#     Can't uninstall 'pyarrow'. No files were found to uninstall.
#   Attempting uninstall: protobuf
#     WARNING: No metadata found in /usr/local/lib/python3.10/dist-packages
#     Found existing installation: protobuf 3.20.3
#     Can't uninstall 'protobuf'. No files were found to uninstall.
#   Attempting uninstall: fsspec
#     WARNING: No metadata found in /usr/local/lib/python3.10/dist-packages
#     Found existing installation: fsspec 2024.6.1
#     Can't uninstall 'fsspec'. No files were found to uninstall.
#   Attempting uninstall: transformers
#     WARNING: No metadata found in /usr/local/lib/python3.10/dist-packages
#     Found existing installation: transformers 4.42.4
#     Can't uninstall 'transformers'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires protobuf<5,>=3.20, but you have protobuf 5.27.2 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.5.0 which is incompatible.
# google-ai-generativelanguage 0.6.6 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-aiplatform 1.59.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-bigquery-storage 2.25.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.2 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# tensorflow 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.27.2 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.27.2 which is incompatible.
# Successfully installed auto-gptq-0.7.1 auto-round-0.2 datasets-2.20.0 deprecated-1.2.14 dill-0.3.8 fsspec-2024.5.0 gekko-1.2.1 gptqmodel-0.9.9+cu1222 intel_extension_for_transformers-1.4.2 multiprocess-0.70.16 neural-compressor-2.6 ninja-1.11.1.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 peft-0.12.0 protobuf-5.27.2 pyarrow-17.0.0 requests-2.32.3 rouge-1.0.1 schema-0.7.7 sentencepiece-0.2.0 transformers-4.43.3 xxhash-3.4.1

# %% [markdown]
# ### Simple GPTQ Quantization
#
# Using the WikiText2 dataset and microsoft/Phi-3-mini-128k-instruct.

# %%
import torch
import logging
from gptqmodel import GPTQModel, QuantizeConfig
from transformers import AutoTokenizer
from datasets import load_dataset


pretrained_model_id = "microsoft/Phi-3-mini-128k-instruct"
quantized_model_id = "Phi-3-mini-128k-instruct-4bit-128g"


def get_wikitext2(tokenizer, nsamples, seqlen):
    traindata = load_dataset("wikitext", "wikitext-2-raw-v1", split="train").filter(
        lambda x: len(x["text"]) >= seqlen
    )

    return [tokenizer(example["text"]) for example in traindata.select(range(nsamples))]


@torch.no_grad()
def calculate_avg_ppl(model, tokenizer):
    from gptqmodel.utils import Perplexity

    ppl = Perplexity(
        model=model,
        tokenizer=tokenizer,
        dataset_path="wikitext",
        dataset_name="wikitext-2-raw-v1",
        split="train",
        text_column="text",
    )

    # n_ctx is context size
    # n_batch is the batch size
    all = ppl.calculate(n_ctx=128, n_batch=128)

    # average ppl
    avg = sum(all) / len(all)

    return avg


def main():
    tokenizer = AutoTokenizer.from_pretrained(pretrained_model_id, use_fast=True)

    print("Loading WikiText2 training data...")
    train_dataset = get_wikitext2(tokenizer, nsamples=512, seqlen=1024)
    print("Completed loading of WikiText2 training data!")

    quantize_config = QuantizeConfig(
        # quantize model to 4-bit
        bits=4,
        # 128 offer good balance between inference speed and quantization quality
        group_size=128,  # it is recommended to set the value to 128
        # increase damp if NaN is encountered during `.quantize()` and/or increase calibration dataset size
        damp_percent=0.01,
        desc_act=True,
        static_groups=False,
        sym=True,
        true_sequential=True,
        lm_head=False,
        # marlin is vLLM's preferred GPTQ quantization method, which is included in "gptq"
        quant_method="gptq",
    )

    # load un-quantized model, the model will always be force loaded into cpu
    model = GPTQModel.from_pretrained(pretrained_model_id, quantize_config)

    print("Beginning quantization...")
    # quantize model, the calibration_dataset should be list of dict whose keys can only be "input_ids" and "attention_mask"
    # with value under torch.LongTensor type.
    model.quantize(train_dataset)
    print("Quantization complete!")

    print("Saving quantized model...")
    # save quantized model
    model.save_quantized(quantized_model_id)
    # save quantized model using safetensors
    model.save_quantized(quantized_model_id, use_safetensors=True)
    print("Saving quantized model complete!")

    # load quantized model, currently only support cpu or single gpu
    model = GPTQModel.from_quantized(quantized_model_id, device="cuda:0")

    # inference with model.generate
    print(
        tokenizer.decode(
            model.generate(
                **tokenizer("What is the capital of Jamaica?", return_tensors="pt").to(
                    "cuda:0"
                )
            )[0]
        )
    )

    print(
        f"Quantized Model {quantized_model_id} avg PPL is {calculate_avg_ppl(model, tokenizer)}"
    )

# set logging configuration for GPTQModel
logging.basicConfig(
    format="%(asctime)s %(levelname)s [%(name)s] %(message)s",
    level=logging.INFO,
    datefmt="%Y-%m-%d %H:%M:%S",
)

# execute main method
main()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# Loading WikiText2 training data...
# Downloading readme:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/733k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/657k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Completed loading of WikiText2 training data!
# config.json:   0%|          | 0.00/3.48k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Beginning quantization...
# Quantizing layer 1 of 32:   0%|          | 0/32 [00:00<?, ?it/s]You are not running the flash-attention implementation, expect numerical differences.
# Quantizing self_attn.qkv_proj in layer 1 of 32:   0%|          | 0/32 [00:03<?, ?it/s]INFO - {'layer': 1, 'module': 'self_attn.qkv_proj', 'avg_loss': '0.2672', 'time': '2.3676'}
# Quantizing self_attn.o_proj in layer 1 of 32:   0%|          | 0/32 [00:07<?, ?it/s]  INFO - {'layer': 1, 'module': 'self_attn.o_proj', 'avg_loss': '0.0004', 'time': '1.2133'}
# Quantizing mlp.gate_up_proj in layer 1 of 32:   0%|          | 0/32 [00:11<?, ?it/s]INFO - {'layer': 1, 'module': 'mlp.gate_up_proj', 'avg_loss': '0.1119', 'time': '1.2600'}
# Quantizing mlp.down_proj in layer 1 of 32:   0%|          | 0/32 [00:19<?, ?it/s]   INFO - {'layer': 1, 'module': 'mlp.down_proj', 'avg_loss': '0.0023', 'time': '3.4561'}
# Quantizing self_attn.qkv_proj in layer 2 of 32:   3%|▎         | 1/32 [00:26<12:42, 24.61s/it]INFO - {'layer': 2, 'module': 'self_attn.qkv_proj', 'avg_loss': '0.4734', 'time': '1.2569'}
# Quantizing self_attn.o_proj in layer 2 of 32:   3%|▎         | 1/32 [00:30<12:42, 24.61s/it]  INFO - {'layer': 2, 'module': 'self_attn.o_proj', 'avg_loss': '0.0061', 'time': '1.1983'}
# Quantizing mlp.gate_up_proj in layer 2 of 32:   3%|▎         | 1/32 [00:33<12:42, 24.61s/it]INFO - {'layer': 2, 'module': 'mlp.gate_up_proj', 'avg_loss': '0.6057', 'time': '1.2693'}
# Quantizing mlp.down_proj in layer 2 of 32:   3%|▎         | 1/32 [00:41<12:42, 24.61s/it]   INFO - {'layer': 2, 'module': 'mlp.down_proj', 'avg_loss': '0.0262', 'time': '3.4432'}
# Quantizing self_attn.qkv_proj in layer 3 of 32:   6%|▋         | 2/32 [00:49<11:34, 23.16s/it]INFO - {'layer': 3, 'module': 'self_attn.qkv_proj', 'avg_loss': '0.5156', 'time': '1.2460'}
# Quantizing self_attn.o_proj in layer 3 of 32:   6%|▋         | 2/32 [00:52<11:34, 23.16s/it]  INFO - {'layer': 3, 'module': 'self_attn.o_proj', 'avg_loss': '0.0118', 'time': '1.1854'}
# Quantizing mlp.gate_up_proj in layer 3 of 32:   6%|▋         | 2/32 [00:55<11:34, 23.16s/it]INFO - {'layer': 3, 'module': 'mlp.gate_up_proj', 'avg_loss': '1.4764', 'time': '1.2807'}
# Quantizing mlp.down_proj in layer 3 of 32:   6%|▋         | 2/32 [01:03<11:34, 23.16s/it]   INFO - {'layer': 3, 'module': 'mlp.down_proj', 'avg_loss': '1.8144', 'time': '3.3798'}
# Quantizing self_attn.qkv_proj in layer 4 of 32:   9%|▉         | 3/32 [01:11<10:56, 22.65s/it]INFO - {'layer': 4, 'module': 'self_attn.qkv_proj', 'avg_loss': '2.7770', 'time': '1.2273'}
# Quantizing self_attn.o_proj in layer 4 of 32:   9%|▉         | 3/32 [01:14<10:56, 22.65s/it]  INFO - {'layer': 4, 'module': 'self_attn.o_proj', 'avg_loss': '0.0286', 'time': '1.1867'}
# Quantizing mlp.gate_up_proj in layer 4 of 32:   9%|▉         | 3/32 [01:18<10:56, 22.65s/it]INFO - {'layer': 4, 'module': 'mlp.gate_up_proj', 'avg_loss': '2.5983', 'time': '1.2748'}
# Quantizing mlp.down_proj in layer 4 of 32:   9%|▉         | 3/32 [01:25<10:56, 22.65s/it]   INFO - {'layer': 4, 'module': 'mlp.down_proj', 'avg_loss': '0.1214', 'time': '3.4129'}
# Quantizing self_attn.qkv_proj in layer 5 of 32:  12%|█▎        | 4/32 [01:33<10:28, 22.44s/it]INFO - {'layer': 5, 'module': 'self_attn.qkv_proj', 'avg_loss': '6.6906', 'time': '1.2361'}
# Quantizing self_attn.o_proj in layer 5 of 32:  12%|█▎        | 4/32 [01:36<10:28, 22.44s/it]  INFO - {'layer': 5, 'module': 'self_attn.o_proj', 'avg_loss': '0.0431', 'time': '1.2147'}
# Quantizing mlp.gate_up_proj in layer 5 of 32:  12%|█▎        | 4/32 [01:40<10:28, 22.44s/it]INFO - {'layer': 5, 'module': 'mlp.gate_up_proj', 'avg_loss': '3.9127', 'time': '1.2609'}
# Quantizing mlp.down_proj in layer 5 of 32:  12%|█▎        | 4/32 [01:47<10:28, 22.44s/it]   INFO - {'layer': 5, 'module': 'mlp.down_proj', 'avg_loss': '1.1193', 'time': '3.4095'}
# Quantizing self_attn.qkv_proj in layer 6 of 32:  16%|█▌        | 5/32 [01:55<10:03, 22.36s/it]INFO - {'layer': 6, 'module': 'self_attn.qkv_proj', 'avg_loss': '8.9559', 'time': '1.2316'}
# Quantizing self_attn.o_proj in layer 6 of 32:  16%|█▌        | 5/32 [01:58<10:03, 22.36s/it]  INFO - {'layer': 6, 'module': 'self_attn.o_proj', 'avg_loss': '0.0718', 'time': '1.2263'}
# Quantizing mlp.gate_up_proj in layer 6 of 32:  16%|█▌        | 5/32 [02:02<10:03, 22.36s/it]INFO - {'layer': 6, 'module': 'mlp.gate_up_proj', 'avg_loss': '4.8502', 'time': '1.2647'}
# Quantizing mlp.down_proj in layer 6 of 32:  16%|█▌        | 5/32 [02:10<10:03, 22.36s/it]   INFO - {'layer': 6, 'module': 'mlp.down_proj', 'avg_loss': '0.3200', 'time': '3.4535'}
# Quantizing self_attn.qkv_proj in layer 7 of 32:  19%|█▉        | 6/32 [02:17<09:40, 22.32s/it]INFO - {'layer': 7, 'module': 'self_attn.qkv_proj', 'avg_loss': '11.3210', 'time': '1.2258'}
# Quantizing self_attn.o_proj in layer 7 of 32:  19%|█▉        | 6/32 [02:21<09:40, 22.32s/it]  INFO - {'layer': 7, 'module': 'self_attn.o_proj', 'avg_loss': '0.1220', 'time': '1.2064'}
# Quantizing mlp.gate_up_proj in layer 7 of 32:  19%|█▉        | 6/32 [02:24<09:40, 22.32s/it]INFO - {'layer': 7, 'module': 'mlp.gate_up_proj', 'avg_loss': '5.9776', 'time': '1.2583'}
# Quantizing mlp.down_proj in layer 7 of 32:  19%|█▉        | 6/32 [02:32<09:40, 22.32s/it]   INFO - {'layer': 7, 'module': 'mlp.down_proj', 'avg_loss': '0.4849', 'time': '3.5388'}
# Quantizing self_attn.qkv_proj in layer 8 of 32:  22%|██▏       | 7/32 [02:39<09:17, 22.32s/it]INFO - {'layer': 8, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.4046', 'time': '1.2311'}
# Quantizing self_attn.o_proj in layer 8 of 32:  22%|██▏       | 7/32 [02:43<09:17, 22.32s/it]  INFO - {'layer': 8, 'module': 'self_attn.o_proj', 'avg_loss': '0.2143', 'time': '1.2138'}
# Quantizing mlp.gate_up_proj in layer 8 of 32:  22%|██▏       | 7/32 [02:46<09:17, 22.32s/it]INFO - {'layer': 8, 'module': 'mlp.gate_up_proj', 'avg_loss': '7.4677', 'time': '1.3303'}
# Quantizing mlp.down_proj in layer 8 of 32:  22%|██▏       | 7/32 [02:54<09:17, 22.32s/it]   INFO - {'layer': 8, 'module': 'mlp.down_proj', 'avg_loss': '0.8095', 'time': '3.3926'}
# Quantizing self_attn.qkv_proj in layer 9 of 32:  25%|██▌       | 8/32 [03:02<08:54, 22.28s/it]INFO - {'layer': 9, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.3153', 'time': '1.2356'}
# Quantizing self_attn.o_proj in layer 9 of 32:  25%|██▌       | 8/32 [03:05<08:54, 22.28s/it]  INFO - {'layer': 9, 'module': 'self_attn.o_proj', 'avg_loss': '0.2954', 'time': '1.2039'}
# Quantizing mlp.gate_up_proj in layer 9 of 32:  25%|██▌       | 8/32 [03:09<08:54, 22.28s/it]INFO - {'layer': 9, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.1468', 'time': '1.2775'}
# Quantizing mlp.down_proj in layer 9 of 32:  25%|██▌       | 8/32 [03:16<08:54, 22.28s/it]   INFO - {'layer': 9, 'module': 'mlp.down_proj', 'avg_loss': '0.9538', 'time': '3.4193'}
# Quantizing self_attn.qkv_proj in layer 10 of 32:  28%|██▊       | 9/32 [03:24<08:32, 22.27s/it]INFO - {'layer': 10, 'module': 'self_attn.qkv_proj', 'avg_loss': '11.5071', 'time': '1.2392'}
# Quantizing self_attn.o_proj in layer 10 of 32:  28%|██▊       | 9/32 [03:27<08:32, 22.27s/it]  INFO - {'layer': 10, 'module': 'self_attn.o_proj', 'avg_loss': '0.4202', 'time': '1.1936'}
# Quantizing mlp.gate_up_proj in layer 10 of 32:  28%|██▊       | 9/32 [03:31<08:32, 22.27s/it]INFO - {'layer': 10, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.0813', 'time': '1.2608'}
# Quantizing mlp.down_proj in layer 10 of 32:  28%|██▊       | 9/32 [03:39<08:32, 22.27s/it]   INFO - {'layer': 10, 'module': 'mlp.down_proj', 'avg_loss': '1.0635', 'time': '3.4087'}
# Quantizing self_attn.qkv_proj in layer 11 of 32:  31%|███▏      | 10/32 [03:46<08:09, 22.27s/it]INFO - {'layer': 11, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.8600', 'time': '1.2305'}
# Quantizing self_attn.o_proj in layer 11 of 32:  31%|███▏      | 10/32 [03:50<08:09, 22.27s/it]  INFO - {'layer': 11, 'module': 'self_attn.o_proj', 'avg_loss': '0.4976', 'time': '1.2039'}
# Quantizing mlp.gate_up_proj in layer 11 of 32:  31%|███▏      | 10/32 [03:53<08:09, 22.27s/it]INFO - {'layer': 11, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.6521', 'time': '1.2886'}
# Quantizing mlp.down_proj in layer 11 of 32:  31%|███▏      | 10/32 [04:01<08:09, 22.27s/it]   INFO - {'layer': 11, 'module': 'mlp.down_proj', 'avg_loss': '1.2641', 'time': '3.3958'}
# Quantizing self_attn.qkv_proj in layer 12 of 32:  34%|███▍      | 11/32 [04:08<07:47, 22.26s/it]INFO - {'layer': 12, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.6542', 'time': '1.2708'}
# Quantizing self_attn.o_proj in layer 12 of 32:  34%|███▍      | 11/32 [04:12<07:47, 22.26s/it]  INFO - {'layer': 12, 'module': 'self_attn.o_proj', 'avg_loss': '0.6477', 'time': '1.1982'}
# Quantizing mlp.gate_up_proj in layer 12 of 32:  34%|███▍      | 11/32 [04:16<07:47, 22.26s/it]INFO - {'layer': 12, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.6375', 'time': '1.2571'}
# Quantizing mlp.down_proj in layer 12 of 32:  34%|███▍      | 11/32 [04:23<07:47, 22.26s/it]   INFO - {'layer': 12, 'module': 'mlp.down_proj', 'avg_loss': '1.3843', 'time': '3.4320'}
# Quantizing self_attn.qkv_proj in layer 13 of 32:  38%|███▊      | 12/32 [04:31<07:25, 22.27s/it]INFO - {'layer': 13, 'module': 'self_attn.qkv_proj', 'avg_loss': '15.0872', 'time': '1.2200'}
# Quantizing self_attn.o_proj in layer 13 of 32:  38%|███▊      | 12/32 [04:34<07:25, 22.27s/it]  INFO - {'layer': 13, 'module': 'self_attn.o_proj', 'avg_loss': '0.6214', 'time': '1.2116'}
# Quantizing mlp.gate_up_proj in layer 13 of 32:  38%|███▊      | 12/32 [04:38<07:25, 22.27s/it]INFO - {'layer': 13, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.7002', 'time': '1.3021'}
# Quantizing mlp.down_proj in layer 13 of 32:  38%|███▊      | 12/32 [04:46<07:25, 22.27s/it]   INFO - {'layer': 13, 'module': 'mlp.down_proj', 'avg_loss': '1.5304', 'time': '3.3972'}
# Quantizing self_attn.qkv_proj in layer 14 of 32:  41%|████      | 13/32 [04:53<07:03, 22.29s/it]INFO - {'layer': 14, 'module': 'self_attn.qkv_proj', 'avg_loss': '16.3492', 'time': '1.2335'}
# Quantizing self_attn.o_proj in layer 14 of 32:  41%|████      | 13/32 [04:57<07:03, 22.29s/it]  INFO - {'layer': 14, 'module': 'self_attn.o_proj', 'avg_loss': '0.6856', 'time': '1.2545'}
# Quantizing mlp.gate_up_proj in layer 14 of 32:  41%|████      | 13/32 [05:00<07:03, 22.29s/it]INFO - {'layer': 14, 'module': 'mlp.gate_up_proj', 'avg_loss': '9.1703', 'time': '1.2697'}
# Quantizing mlp.down_proj in layer 14 of 32:  41%|████      | 13/32 [05:08<07:03, 22.29s/it]   INFO - {'layer': 14, 'module': 'mlp.down_proj', 'avg_loss': '3.9257', 'time': '3.4527'}
# Quantizing self_attn.qkv_proj in layer 15 of 32:  44%|████▍     | 14/32 [05:16<06:42, 22.37s/it]INFO - {'layer': 15, 'module': 'self_attn.qkv_proj', 'avg_loss': '15.1300', 'time': '1.2422'}
# Quantizing self_attn.o_proj in layer 15 of 32:  44%|████▍     | 14/32 [05:19<06:42, 22.37s/it]  INFO - {'layer': 15, 'module': 'self_attn.o_proj', 'avg_loss': '0.9811', 'time': '1.1970'}
# Quantizing mlp.gate_up_proj in layer 15 of 32:  44%|████▍     | 14/32 [05:23<06:42, 22.37s/it]INFO - {'layer': 15, 'module': 'mlp.gate_up_proj', 'avg_loss': '9.2223', 'time': '1.2663'}
# Quantizing mlp.down_proj in layer 15 of 32:  44%|████▍     | 14/32 [05:31<06:42, 22.37s/it]   INFO - {'layer': 15, 'module': 'mlp.down_proj', 'avg_loss': '2.0157', 'time': '3.4284'}
# Quantizing self_attn.qkv_proj in layer 16 of 32:  47%|████▋     | 15/32 [05:38<06:21, 22.41s/it]INFO - {'layer': 16, 'module': 'self_attn.qkv_proj', 'avg_loss': '15.1643', 'time': '1.2413'}
# Quantizing self_attn.o_proj in layer 16 of 32:  47%|████▋     | 15/32 [05:42<06:21, 22.41s/it]  INFO - {'layer': 16, 'module': 'self_attn.o_proj', 'avg_loss': '1.0993', 'time': '1.1878'}
# Quantizing mlp.gate_up_proj in layer 16 of 32:  47%|████▋     | 15/32 [05:45<06:21, 22.41s/it]INFO - {'layer': 16, 'module': 'mlp.gate_up_proj', 'avg_loss': '9.4649', 'time': '1.2999'}
# Quantizing mlp.down_proj in layer 16 of 32:  47%|████▋     | 15/32 [05:53<06:21, 22.41s/it]   INFO - {'layer': 16, 'module': 'mlp.down_proj', 'avg_loss': '2.2844', 'time': '3.4342'}
# Quantizing self_attn.qkv_proj in layer 17 of 32:  50%|█████     | 16/32 [06:01<05:59, 22.45s/it]INFO - {'layer': 17, 'module': 'self_attn.qkv_proj', 'avg_loss': '16.7755', 'time': '1.2574'}
# Quantizing self_attn.o_proj in layer 17 of 32:  50%|█████     | 16/32 [06:04<05:59, 22.45s/it]  INFO - {'layer': 17, 'module': 'self_attn.o_proj', 'avg_loss': '1.0929', 'time': '1.2147'}
# Quantizing mlp.gate_up_proj in layer 17 of 32:  50%|█████     | 16/32 [06:08<05:59, 22.45s/it]INFO - {'layer': 17, 'module': 'mlp.gate_up_proj', 'avg_loss': '10.3315', 'time': '1.2977'}
# Quantizing mlp.down_proj in layer 17 of 32:  50%|█████     | 16/32 [06:16<05:59, 22.45s/it]   INFO - {'layer': 17, 'module': 'mlp.down_proj', 'avg_loss': '2.8137', 'time': '3.3858'}
# Quantizing self_attn.qkv_proj in layer 18 of 32:  53%|█████▎    | 17/32 [06:23<05:36, 22.43s/it]INFO - {'layer': 18, 'module': 'self_attn.qkv_proj', 'avg_loss': '17.7620', 'time': '1.2268'}
# Quantizing self_attn.o_proj in layer 18 of 32:  53%|█████▎    | 17/32 [06:27<05:36, 22.43s/it]  INFO - {'layer': 18, 'module': 'self_attn.o_proj', 'avg_loss': '1.4635', 'time': '1.1907'}
# Quantizing mlp.gate_up_proj in layer 18 of 32:  53%|█████▎    | 17/32 [06:30<05:36, 22.43s/it]INFO - {'layer': 18, 'module': 'mlp.gate_up_proj', 'avg_loss': '11.7404', 'time': '1.4118'}
# Quantizing mlp.down_proj in layer 18 of 32:  53%|█████▎    | 17/32 [06:38<05:36, 22.43s/it]   INFO - {'layer': 18, 'module': 'mlp.down_proj', 'avg_loss': '3.8711', 'time': '3.4040'}
# Quantizing self_attn.qkv_proj in layer 19 of 32:  56%|█████▋    | 18/32 [06:46<05:14, 22.46s/it]INFO - {'layer': 19, 'module': 'self_attn.qkv_proj', 'avg_loss': '17.8012', 'time': '1.2317'}
# Quantizing self_attn.o_proj in layer 19 of 32:  56%|█████▋    | 18/32 [06:49<05:14, 22.46s/it]  INFO - {'layer': 19, 'module': 'self_attn.o_proj', 'avg_loss': '1.9424', 'time': '1.2603'}
# Quantizing mlp.gate_up_proj in layer 19 of 32:  56%|█████▋    | 18/32 [06:53<05:14, 22.46s/it]INFO - {'layer': 19, 'module': 'mlp.gate_up_proj', 'avg_loss': '13.1216', 'time': '1.2677'}
# Quantizing mlp.down_proj in layer 19 of 32:  56%|█████▋    | 18/32 [07:01<05:14, 22.46s/it]   INFO - {'layer': 19, 'module': 'mlp.down_proj', 'avg_loss': '5.2772', 'time': '3.3982'}
# Quantizing self_attn.qkv_proj in layer 20 of 32:  59%|█████▉    | 19/32 [07:08<04:52, 22.49s/it]INFO - {'layer': 20, 'module': 'self_attn.qkv_proj', 'avg_loss': '18.0537', 'time': '1.2375'}
# Quantizing self_attn.o_proj in layer 20 of 32:  59%|█████▉    | 19/32 [07:12<04:52, 22.49s/it]  INFO - {'layer': 20, 'module': 'self_attn.o_proj', 'avg_loss': '1.7404', 'time': '1.1827'}
# Quantizing mlp.gate_up_proj in layer 20 of 32:  59%|█████▉    | 19/32 [07:15<04:52, 22.49s/it]INFO - {'layer': 20, 'module': 'mlp.gate_up_proj', 'avg_loss': '15.2978', 'time': '1.3074'}
# Quantizing mlp.down_proj in layer 20 of 32:  59%|█████▉    | 19/32 [07:23<04:52, 22.49s/it]   INFO - {'layer': 20, 'module': 'mlp.down_proj', 'avg_loss': '6.6629', 'time': '3.4032'}
# Quantizing self_attn.qkv_proj in layer 21 of 32:  62%|██████▎   | 20/32 [07:31<04:29, 22.47s/it]INFO - {'layer': 21, 'module': 'self_attn.qkv_proj', 'avg_loss': '20.7444', 'time': '1.2380'}
# Quantizing self_attn.o_proj in layer 21 of 32:  62%|██████▎   | 20/32 [07:34<04:29, 22.47s/it]  INFO - {'layer': 21, 'module': 'self_attn.o_proj', 'avg_loss': '2.3355', 'time': '1.2006'}
# Quantizing mlp.gate_up_proj in layer 21 of 32:  62%|██████▎   | 20/32 [07:38<04:29, 22.47s/it]INFO - {'layer': 21, 'module': 'mlp.gate_up_proj', 'avg_loss': '17.4645', 'time': '1.2737'}
# Quantizing mlp.down_proj in layer 21 of 32:  62%|██████▎   | 20/32 [07:45<04:29, 22.47s/it]   INFO - {'layer': 21, 'module': 'mlp.down_proj', 'avg_loss': '8.4123', 'time': '3.5845'}
# Quantizing self_attn.qkv_proj in layer 22 of 32:  66%|██████▌   | 21/32 [07:53<04:07, 22.52s/it]INFO - {'layer': 22, 'module': 'self_attn.qkv_proj', 'avg_loss': '22.8102', 'time': '1.2605'}
# Quantizing self_attn.o_proj in layer 22 of 32:  66%|██████▌   | 21/32 [07:57<04:07, 22.52s/it]  INFO - {'layer': 22, 'module': 'self_attn.o_proj', 'avg_loss': '2.3985', 'time': '1.1897'}
# Quantizing mlp.gate_up_proj in layer 22 of 32:  66%|██████▌   | 21/32 [08:00<04:07, 22.52s/it]INFO - {'layer': 22, 'module': 'mlp.gate_up_proj', 'avg_loss': '20.2661', 'time': '1.2662'}
# Quantizing mlp.down_proj in layer 22 of 32:  66%|██████▌   | 21/32 [08:08<04:07, 22.52s/it]   INFO - {'layer': 22, 'module': 'mlp.down_proj', 'avg_loss': '11.3656', 'time': '3.4795'}
# Quantizing self_attn.qkv_proj in layer 23 of 32:  69%|██████▉   | 22/32 [08:16<03:45, 22.51s/it]INFO - {'layer': 23, 'module': 'self_attn.qkv_proj', 'avg_loss': '24.5657', 'time': '1.2512'}
# Quantizing self_attn.o_proj in layer 23 of 32:  69%|██████▉   | 22/32 [08:19<03:45, 22.51s/it]  INFO - {'layer': 23, 'module': 'self_attn.o_proj', 'avg_loss': '3.0651', 'time': '1.2249'}
# Quantizing mlp.gate_up_proj in layer 23 of 32:  69%|██████▉   | 22/32 [08:23<03:45, 22.51s/it]INFO - {'layer': 23, 'module': 'mlp.gate_up_proj', 'avg_loss': '22.9631', 'time': '1.4072'}
# Quantizing mlp.down_proj in layer 23 of 32:  69%|██████▉   | 22/32 [08:31<03:45, 22.51s/it]   INFO - {'layer': 23, 'module': 'mlp.down_proj', 'avg_loss': '15.1750', 'time': '3.4353'}
# Quantizing self_attn.qkv_proj in layer 24 of 32:  72%|███████▏  | 23/32 [08:38<03:22, 22.55s/it]INFO - {'layer': 24, 'module': 'self_attn.qkv_proj', 'avg_loss': '28.0236', 'time': '1.2584'}
# Quantizing self_attn.o_proj in layer 24 of 32:  72%|███████▏  | 23/32 [08:42<03:22, 22.55s/it]  INFO - {'layer': 24, 'module': 'self_attn.o_proj', 'avg_loss': '3.3871', 'time': '1.2201'}
# Quantizing mlp.gate_up_proj in layer 24 of 32:  72%|███████▏  | 23/32 [08:46<03:22, 22.55s/it]INFO - {'layer': 24, 'module': 'mlp.gate_up_proj', 'avg_loss': '26.5902', 'time': '1.4273'}
# Quantizing mlp.down_proj in layer 24 of 32:  72%|███████▏  | 23/32 [08:53<03:22, 22.55s/it]   INFO - {'layer': 24, 'module': 'mlp.down_proj', 'avg_loss': '19.1169', 'time': '3.5243'}
# Quantizing self_attn.qkv_proj in layer 25 of 32:  75%|███████▌  | 24/32 [09:01<03:00, 22.62s/it]INFO - {'layer': 25, 'module': 'self_attn.qkv_proj', 'avg_loss': '29.8331', 'time': '1.2311'}
# Quantizing self_attn.o_proj in layer 25 of 32:  75%|███████▌  | 24/32 [09:05<03:00, 22.62s/it]  INFO - {'layer': 25, 'module': 'self_attn.o_proj', 'avg_loss': '4.5721', 'time': '1.1929'}
# Quantizing mlp.gate_up_proj in layer 25 of 32:  75%|███████▌  | 24/32 [09:08<03:00, 22.62s/it]INFO - {'layer': 25, 'module': 'mlp.gate_up_proj', 'avg_loss': '29.8112', 'time': '1.3216'}
# Quantizing mlp.down_proj in layer 25 of 32:  75%|███████▌  | 24/32 [09:16<03:00, 22.62s/it]   INFO - {'layer': 25, 'module': 'mlp.down_proj', 'avg_loss': '24.6754', 'time': '3.3843'}
# Quantizing self_attn.qkv_proj in layer 26 of 32:  78%|███████▊  | 25/32 [09:24<02:38, 22.58s/it]INFO - {'layer': 26, 'module': 'self_attn.qkv_proj', 'avg_loss': '34.0795', 'time': '1.2343'}
# Quantizing self_attn.o_proj in layer 26 of 32:  78%|███████▊  | 25/32 [09:27<02:38, 22.58s/it]  INFO - {'layer': 26, 'module': 'self_attn.o_proj', 'avg_loss': '4.8549', 'time': '1.2437'}
# Quantizing mlp.gate_up_proj in layer 26 of 32:  78%|███████▊  | 25/32 [09:31<02:38, 22.58s/it]INFO - {'layer': 26, 'module': 'mlp.gate_up_proj', 'avg_loss': '33.2029', 'time': '1.2715'}
# Quantizing mlp.down_proj in layer 26 of 32:  78%|███████▊  | 25/32 [09:39<02:38, 22.58s/it]   INFO - {'layer': 26, 'module': 'mlp.down_proj', 'avg_loss': '34.0434', 'time': '3.4438'}
# Quantizing self_attn.qkv_proj in layer 27 of 32:  81%|████████▏ | 26/32 [09:46<02:15, 22.59s/it]INFO - {'layer': 27, 'module': 'self_attn.qkv_proj', 'avg_loss': '35.3528', 'time': '1.2396'}
# Quantizing self_attn.o_proj in layer 27 of 32:  81%|████████▏ | 26/32 [09:50<02:15, 22.59s/it]  INFO - {'layer': 27, 'module': 'self_attn.o_proj', 'avg_loss': '5.5931', 'time': '1.2065'}
# Quantizing mlp.gate_up_proj in layer 27 of 32:  81%|████████▏ | 26/32 [09:53<02:15, 22.59s/it]INFO - {'layer': 27, 'module': 'mlp.gate_up_proj', 'avg_loss': '37.4242', 'time': '1.3020'}
# Quantizing mlp.down_proj in layer 27 of 32:  81%|████████▏ | 26/32 [10:01<02:15, 22.59s/it]   INFO - {'layer': 27, 'module': 'mlp.down_proj', 'avg_loss': '36.0296', 'time': '3.4423'}
# Quantizing self_attn.qkv_proj in layer 28 of 32:  84%|████████▍ | 27/32 [10:09<01:52, 22.59s/it]INFO - {'layer': 28, 'module': 'self_attn.qkv_proj', 'avg_loss': '39.6745', 'time': '1.2437'}
# Quantizing self_attn.o_proj in layer 28 of 32:  84%|████████▍ | 27/32 [10:12<01:52, 22.59s/it]  INFO - {'layer': 28, 'module': 'self_attn.o_proj', 'avg_loss': '5.9618', 'time': '1.2120'}
# Quantizing mlp.gate_up_proj in layer 28 of 32:  84%|████████▍ | 27/32 [10:16<01:52, 22.59s/it]INFO - {'layer': 28, 'module': 'mlp.gate_up_proj', 'avg_loss': '41.0127', 'time': '1.2803'}
# Quantizing mlp.down_proj in layer 28 of 32:  84%|████████▍ | 27/32 [10:24<01:52, 22.59s/it]   INFO - {'layer': 28, 'module': 'mlp.down_proj', 'avg_loss': '41.2711', 'time': '3.4132'}
# Quantizing self_attn.qkv_proj in layer 29 of 32:  88%|████████▊ | 28/32 [10:32<01:30, 22.60s/it]INFO - {'layer': 29, 'module': 'self_attn.qkv_proj', 'avg_loss': '41.6779', 'time': '1.2483'}
# Quantizing self_attn.o_proj in layer 29 of 32:  88%|████████▊ | 28/32 [10:35<01:30, 22.60s/it]  INFO - {'layer': 29, 'module': 'self_attn.o_proj', 'avg_loss': '10.1907', 'time': '1.1905'}
# Quantizing mlp.gate_up_proj in layer 29 of 32:  88%|████████▊ | 28/32 [10:39<01:30, 22.60s/it]INFO - {'layer': 29, 'module': 'mlp.gate_up_proj', 'avg_loss': '46.4294', 'time': '1.2772'}
# Quantizing mlp.down_proj in layer 29 of 32:  88%|████████▊ | 28/32 [10:46<01:30, 22.60s/it]   INFO - {'layer': 29, 'module': 'mlp.down_proj', 'avg_loss': '49.9661', 'time': '3.4535'}
# Quantizing self_attn.qkv_proj in layer 30 of 32:  91%|█████████ | 29/32 [10:54<01:07, 22.59s/it]INFO - {'layer': 30, 'module': 'self_attn.qkv_proj', 'avg_loss': '43.8318', 'time': '1.2346'}
# Quantizing self_attn.o_proj in layer 30 of 32:  91%|█████████ | 29/32 [10:58<01:07, 22.59s/it]  INFO - {'layer': 30, 'module': 'self_attn.o_proj', 'avg_loss': '12.7973', 'time': '1.1895'}
# Quantizing mlp.gate_up_proj in layer 30 of 32:  91%|█████████ | 29/32 [11:01<01:07, 22.59s/it]INFO - {'layer': 30, 'module': 'mlp.gate_up_proj', 'avg_loss': '51.7107', 'time': '1.2548'}
# Quantizing mlp.down_proj in layer 30 of 32:  91%|█████████ | 29/32 [11:09<01:07, 22.59s/it]   INFO - {'layer': 30, 'module': 'mlp.down_proj', 'avg_loss': '66.8333', 'time': '3.4360'}
# Quantizing self_attn.qkv_proj in layer 31 of 32:  94%|█████████▍| 30/32 [11:17<00:45, 22.57s/it]INFO - {'layer': 31, 'module': 'self_attn.qkv_proj', 'avg_loss': '43.2623', 'time': '1.2422'}
# Quantizing self_attn.o_proj in layer 31 of 32:  94%|█████████▍| 30/32 [11:20<00:45, 22.57s/it]  INFO - {'layer': 31, 'module': 'self_attn.o_proj', 'avg_loss': '12.3272', 'time': '1.2192'}
# Quantizing mlp.gate_up_proj in layer 31 of 32:  94%|█████████▍| 30/32 [11:24<00:45, 22.57s/it]INFO - {'layer': 31, 'module': 'mlp.gate_up_proj', 'avg_loss': '54.0788', 'time': '1.2852'}
# Quantizing mlp.down_proj in layer 31 of 32:  94%|█████████▍| 30/32 [11:32<00:45, 22.57s/it]   INFO - {'layer': 31, 'module': 'mlp.down_proj', 'avg_loss': '65.8378', 'time': '3.4301'}
# Quantizing self_attn.qkv_proj in layer 32 of 32:  97%|█████████▋| 31/32 [11:39<00:22, 22.58s/it]INFO - {'layer': 32, 'module': 'self_attn.qkv_proj', 'avg_loss': '36.1396', 'time': '1.2326'}
# Quantizing self_attn.o_proj in layer 32 of 32:  97%|█████████▋| 31/32 [11:43<00:22, 22.58s/it]  INFO - {'layer': 32, 'module': 'self_attn.o_proj', 'avg_loss': '13.4512', 'time': '1.2076'}
# Quantizing mlp.gate_up_proj in layer 32 of 32:  97%|█████████▋| 31/32 [11:46<00:22, 22.58s/it]INFO - {'layer': 32, 'module': 'mlp.gate_up_proj', 'avg_loss': '50.9153', 'time': '1.3078'}
# Quantizing mlp.down_proj in layer 32 of 32:  97%|█████████▋| 31/32 [11:54<00:22, 22.58s/it]   INFO - {'layer': 32, 'module': 'mlp.down_proj', 'avg_loss': '105.2656', 'time': '3.4324'}
# Quantizing mlp.down_proj in layer 32 of 32: 100%|██████████| 32/32 [11:59<00:00, 22.50s/it]
# INFO - Quantization summary:
# [{'layer': 1, 'module': 'self_attn.qkv_proj', 'avg_loss': '0.2672', 'time': '2.3676'}, {'layer': 1, 'module': 'self_attn.o_proj', 'avg_loss': '0.0004', 'time': '1.2133'}, {'layer': 1, 'module': 'mlp.gate_up_proj', 'avg_loss': '0.1119', 'time': '1.2600'}, {'layer': 1, 'module': 'mlp.down_proj', 'avg_loss': '0.0023', 'time': '3.4561'}, {'layer': 2, 'module': 'self_attn.qkv_proj', 'avg_loss': '0.4734', 'time': '1.2569'}, {'layer': 2, 'module': 'self_attn.o_proj', 'avg_loss': '0.0061', 'time': '1.1983'}, {'layer': 2, 'module': 'mlp.gate_up_proj', 'avg_loss': '0.6057', 'time': '1.2693'}, {'layer': 2, 'module': 'mlp.down_proj', 'avg_loss': '0.0262', 'time': '3.4432'}, {'layer': 3, 'module': 'self_attn.qkv_proj', 'avg_loss': '0.5156', 'time': '1.2460'}, {'layer': 3, 'module': 'self_attn.o_proj', 'avg_loss': '0.0118', 'time': '1.1854'}, {'layer': 3, 'module': 'mlp.gate_up_proj', 'avg_loss': '1.4764', 'time': '1.2807'}, {'layer': 3, 'module': 'mlp.down_proj', 'avg_loss': '1.8144', 'time': '3.3798'}, {'layer': 4, 'module': 'self_attn.qkv_proj', 'avg_loss': '2.7770', 'time': '1.2273'}, {'layer': 4, 'module': 'self_attn.o_proj', 'avg_loss': '0.0286', 'time': '1.1867'}, {'layer': 4, 'module': 'mlp.gate_up_proj', 'avg_loss': '2.5983', 'time': '1.2748'}, {'layer': 4, 'module': 'mlp.down_proj', 'avg_loss': '0.1214', 'time': '3.4129'}, {'layer': 5, 'module': 'self_attn.qkv_proj', 'avg_loss': '6.6906', 'time': '1.2361'}, {'layer': 5, 'module': 'self_attn.o_proj', 'avg_loss': '0.0431', 'time': '1.2147'}, {'layer': 5, 'module': 'mlp.gate_up_proj', 'avg_loss': '3.9127', 'time': '1.2609'}, {'layer': 5, 'module': 'mlp.down_proj', 'avg_loss': '1.1193', 'time': '3.4095'}, {'layer': 6, 'module': 'self_attn.qkv_proj', 'avg_loss': '8.9559', 'time': '1.2316'}, {'layer': 6, 'module': 'self_attn.o_proj', 'avg_loss': '0.0718', 'time': '1.2263'}, {'layer': 6, 'module': 'mlp.gate_up_proj', 'avg_loss': '4.8502', 'time': '1.2647'}, {'layer': 6, 'module': 'mlp.down_proj', 'avg_loss': '0.3200', 'time': '3.4535'}, {'layer': 7, 'module': 'self_attn.qkv_proj', 'avg_loss': '11.3210', 'time': '1.2258'}, {'layer': 7, 'module': 'self_attn.o_proj', 'avg_loss': '0.1220', 'time': '1.2064'}, {'layer': 7, 'module': 'mlp.gate_up_proj', 'avg_loss': '5.9776', 'time': '1.2583'}, {'layer': 7, 'module': 'mlp.down_proj', 'avg_loss': '0.4849', 'time': '3.5388'}, {'layer': 8, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.4046', 'time': '1.2311'}, {'layer': 8, 'module': 'self_attn.o_proj', 'avg_loss': '0.2143', 'time': '1.2138'}, {'layer': 8, 'module': 'mlp.gate_up_proj', 'avg_loss': '7.4677', 'time': '1.3303'}, {'layer': 8, 'module': 'mlp.down_proj', 'avg_loss': '0.8095', 'time': '3.3926'}, {'layer': 9, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.3153', 'time': '1.2356'}, {'layer': 9, 'module': 'self_attn.o_proj', 'avg_loss': '0.2954', 'time': '1.2039'}, {'layer': 9, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.1468', 'time': '1.2775'}, {'layer': 9, 'module': 'mlp.down_proj', 'avg_loss': '0.9538', 'time': '3.4193'}, {'layer': 10, 'module': 'self_attn.qkv_proj', 'avg_loss': '11.5071', 'time': '1.2392'}, {'layer': 10, 'module': 'self_attn.o_proj', 'avg_loss': '0.4202', 'time': '1.1936'}, {'layer': 10, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.0813', 'time': '1.2608'}, {'layer': 10, 'module': 'mlp.down_proj', 'avg_loss': '1.0635', 'time': '3.4087'}, {'layer': 11, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.8600', 'time': '1.2305'}, {'layer': 11, 'module': 'self_attn.o_proj', 'avg_loss': '0.4976', 'time': '1.2039'}, {'layer': 11, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.6521', 'time': '1.2886'}, {'layer': 11, 'module': 'mlp.down_proj', 'avg_loss': '1.2641', 'time': '3.3958'}, {'layer': 12, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.6542', 'time': '1.2708'}, {'layer': 12, 'module': 'self_attn.o_proj', 'avg_loss': '0.6477', 'time': '1.1982'}, {'layer': 12, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.6375', 'time': '1.2571'}, {'layer': 12, 'module': 'mlp.down_proj', 'a ...
# INFO - {'layer': 1, 'module': 'self_attn.qkv_proj', 'avg_loss': '0.2672', 'time': '2.3676'}
# INFO - {'layer': 1, 'module': 'self_attn.o_proj', 'avg_loss': '0.0004', 'time': '1.2133'}
# INFO - {'layer': 1, 'module': 'mlp.gate_up_proj', 'avg_loss': '0.1119', 'time': '1.2600'}
# INFO - {'layer': 1, 'module': 'mlp.down_proj', 'avg_loss': '0.0023', 'time': '3.4561'}
# INFO - {'layer': 2, 'module': 'self_attn.qkv_proj', 'avg_loss': '0.4734', 'time': '1.2569'}
# INFO - {'layer': 2, 'module': 'self_attn.o_proj', 'avg_loss': '0.0061', 'time': '1.1983'}
# INFO - {'layer': 2, 'module': 'mlp.gate_up_proj', 'avg_loss': '0.6057', 'time': '1.2693'}
# INFO - {'layer': 2, 'module': 'mlp.down_proj', 'avg_loss': '0.0262', 'time': '3.4432'}
# INFO - {'layer': 3, 'module': 'self_attn.qkv_proj', 'avg_loss': '0.5156', 'time': '1.2460'}
# INFO - {'layer': 3, 'module': 'self_attn.o_proj', 'avg_loss': '0.0118', 'time': '1.1854'}
# INFO - {'layer': 3, 'module': 'mlp.gate_up_proj', 'avg_loss': '1.4764', 'time': '1.2807'}
# INFO - {'layer': 3, 'module': 'mlp.down_proj', 'avg_loss': '1.8144', 'time': '3.3798'}
# INFO - {'layer': 4, 'module': 'self_attn.qkv_proj', 'avg_loss': '2.7770', 'time': '1.2273'}
# INFO - {'layer': 4, 'module': 'self_attn.o_proj', 'avg_loss': '0.0286', 'time': '1.1867'}
# INFO - {'layer': 4, 'module': 'mlp.gate_up_proj', 'avg_loss': '2.5983', 'time': '1.2748'}
# INFO - {'layer': 4, 'module': 'mlp.down_proj', 'avg_loss': '0.1214', 'time': '3.4129'}
# INFO - {'layer': 5, 'module': 'self_attn.qkv_proj', 'avg_loss': '6.6906', 'time': '1.2361'}
# INFO - {'layer': 5, 'module': 'self_attn.o_proj', 'avg_loss': '0.0431', 'time': '1.2147'}
# INFO - {'layer': 5, 'module': 'mlp.gate_up_proj', 'avg_loss': '3.9127', 'time': '1.2609'}
# INFO - {'layer': 5, 'module': 'mlp.down_proj', 'avg_loss': '1.1193', 'time': '3.4095'}
# INFO - {'layer': 6, 'module': 'self_attn.qkv_proj', 'avg_loss': '8.9559', 'time': '1.2316'}
# INFO - {'layer': 6, 'module': 'self_attn.o_proj', 'avg_loss': '0.0718', 'time': '1.2263'}
# INFO - {'layer': 6, 'module': 'mlp.gate_up_proj', 'avg_loss': '4.8502', 'time': '1.2647'}
# INFO - {'layer': 6, 'module': 'mlp.down_proj', 'avg_loss': '0.3200', 'time': '3.4535'}
# INFO - {'layer': 7, 'module': 'self_attn.qkv_proj', 'avg_loss': '11.3210', 'time': '1.2258'}
# INFO - {'layer': 7, 'module': 'self_attn.o_proj', 'avg_loss': '0.1220', 'time': '1.2064'}
# INFO - {'layer': 7, 'module': 'mlp.gate_up_proj', 'avg_loss': '5.9776', 'time': '1.2583'}
# INFO - {'layer': 7, 'module': 'mlp.down_proj', 'avg_loss': '0.4849', 'time': '3.5388'}
# INFO - {'layer': 8, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.4046', 'time': '1.2311'}
# INFO - {'layer': 8, 'module': 'self_attn.o_proj', 'avg_loss': '0.2143', 'time': '1.2138'}
# INFO - {'layer': 8, 'module': 'mlp.gate_up_proj', 'avg_loss': '7.4677', 'time': '1.3303'}
# INFO - {'layer': 8, 'module': 'mlp.down_proj', 'avg_loss': '0.8095', 'time': '3.3926'}
# INFO - {'layer': 9, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.3153', 'time': '1.2356'}
# INFO - {'layer': 9, 'module': 'self_attn.o_proj', 'avg_loss': '0.2954', 'time': '1.2039'}
# INFO - {'layer': 9, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.1468', 'time': '1.2775'}
# INFO - {'layer': 9, 'module': 'mlp.down_proj', 'avg_loss': '0.9538', 'time': '3.4193'}
# INFO - {'layer': 10, 'module': 'self_attn.qkv_proj', 'avg_loss': '11.5071', 'time': '1.2392'}
# INFO - {'layer': 10, 'module': 'self_attn.o_proj', 'avg_loss': '0.4202', 'time': '1.1936'}
# INFO - {'layer': 10, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.0813', 'time': '1.2608'}
# INFO - {'layer': 10, 'module': 'mlp.down_proj', 'avg_loss': '1.0635', 'time': '3.4087'}
# INFO - {'layer': 11, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.8600', 'time': '1.2305'}
# INFO - {'layer': 11, 'module': 'self_attn.o_proj', 'avg_loss': '0.4976', 'time': '1.2039'}
# INFO - {'layer': 11, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.6521', 'time': '1.2886'}
# INFO - {'layer': 11, 'module': 'mlp.down_proj', 'avg_loss': '1.2641', 'time': '3.3958'}
# INFO - {'layer': 12, 'module': 'self_attn.qkv_proj', 'avg_loss': '13.6542', 'time': '1.2708'}
# INFO - {'layer': 12, 'module': 'self_attn.o_proj', 'avg_loss': '0.6477', 'time': '1.1982'}
# INFO - {'layer': 12, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.6375', 'time': '1.2571'}
# INFO - {'layer': 12, 'module': 'mlp.down_proj', 'avg_loss': '1.3843', 'time': '3.4320'}
# INFO - {'layer': 13, 'module': 'self_attn.qkv_proj', 'avg_loss': '15.0872', 'time': '1.2200'}
# INFO - {'layer': 13, 'module': 'self_attn.o_proj', 'avg_loss': '0.6214', 'time': '1.2116'}
# INFO - {'layer': 13, 'module': 'mlp.gate_up_proj', 'avg_loss': '8.7002', 'time': '1.3021'}
# INFO - {'layer': 13, 'module': 'mlp.down_proj', 'avg_loss': '1.5304', 'time': '3.3972'}
# INFO - {'layer': 14, 'module': 'self_attn.qkv_proj', 'avg_loss': '16.3492', 'time': '1.2335'}
# INFO - {'layer': 14, 'module': 'self_attn.o_proj', 'avg_loss': '0.6856', 'time': '1.2545'}
# INFO - {'layer': 14, 'module': 'mlp.gate_up_proj', 'avg_loss': '9.1703', 'time': '1.2697'}
# INFO - {'layer': 14, 'module': 'mlp.down_proj', 'avg_loss': '3.9257', 'time': '3.4527'}
# INFO - {'layer': 15, 'module': 'self_attn.qkv_proj', 'avg_loss': '15.1300', 'time': '1.2422'}
# INFO - {'layer': 15, 'module': 'self_attn.o_proj', 'avg_loss': '0.9811', 'time': '1.1970'}
# INFO - {'layer': 15, 'module': 'mlp.gate_up_proj', 'avg_loss': '9.2223', 'time': '1.2663'}
# INFO - {'layer': 15, 'module': 'mlp.down_proj', 'avg_loss': '2.0157', 'time': '3.4284'}
# INFO - {'layer': 16, 'module': 'self_attn.qkv_proj', 'avg_loss': '15.1643', 'time': '1.2413'}
# INFO - {'layer': 16, 'module': 'self_attn.o_proj', 'avg_loss': '1.0993', 'time': '1.1878'}
# INFO - {'layer': 16, 'module': 'mlp.gate_up_proj', 'avg_loss': '9.4649', 'time': '1.2999'}
# INFO - {'layer': 16, 'module': 'mlp.down_proj', 'avg_loss': '2.2844', 'time': '3.4342'}
# INFO - {'layer': 17, 'module': 'self_attn.qkv_proj', 'avg_loss': '16.7755', 'time': '1.2574'}
# INFO - {'layer': 17, 'module': 'self_attn.o_proj', 'avg_loss': '1.0929', 'time': '1.2147'}
# INFO - {'layer': 17, 'module': 'mlp.gate_up_proj', 'avg_loss': '10.3315', 'time': '1.2977'}
# INFO - {'layer': 17, 'module': 'mlp.down_proj', 'avg_loss': '2.8137', 'time': '3.3858'}
# INFO - {'layer': 18, 'module': 'self_attn.qkv_proj', 'avg_loss': '17.7620', 'time': '1.2268'}
# INFO - {'layer': 18, 'module': 'self_attn.o_proj', 'avg_loss': '1.4635', 'time': '1.1907'}
# INFO - {'layer': 18, 'module': 'mlp.gate_up_proj', 'avg_loss': '11.7404', 'time': '1.4118'}
# INFO - {'layer': 18, 'module': 'mlp.down_proj', 'avg_loss': '3.8711', 'time': '3.4040'}
# INFO - {'layer': 19, 'module': 'self_attn.qkv_proj', 'avg_loss': '17.8012', 'time': '1.2317'}
# INFO - {'layer': 19, 'module': 'self_attn.o_proj', 'avg_loss': '1.9424', 'time': '1.2603'}
# INFO - {'layer': 19, 'module': 'mlp.gate_up_proj', 'avg_loss': '13.1216', 'time': '1.2677'}
# INFO - {'layer': 19, 'module': 'mlp.down_proj', 'avg_loss': '5.2772', 'time': '3.3982'}
# INFO - {'layer': 20, 'module': 'self_attn.qkv_proj', 'avg_loss': '18.0537', 'time': '1.2375'}
# INFO - {'layer': 20, 'module': 'self_attn.o_proj', 'avg_loss': '1.7404', 'time': '1.1827'}
# INFO - {'layer': 20, 'module': 'mlp.gate_up_proj', 'avg_loss': '15.2978', 'time': '1.3074'}
# INFO - {'layer': 20, 'module': 'mlp.down_proj', 'avg_loss': '6.6629', 'time': '3.4032'}
# INFO - {'layer': 21, 'module': 'self_attn.qkv_proj', 'avg_loss': '20.7444', 'time': '1.2380'}
# INFO - {'layer': 21, 'module': 'self_attn.o_proj', 'avg_loss': '2.3355', 'time': '1.2006'}
# INFO - {'layer': 21, 'module': 'mlp.gate_up_proj', 'avg_loss': '17.4645', 'time': '1.2737'}
# INFO - {'layer': 21, 'module': 'mlp.down_proj', 'avg_loss': '8.4123', 'time': '3.5845'}
# INFO - {'layer': 22, 'module': 'self_attn.qkv_proj', 'avg_loss': '22.8102', 'time': '1.2605'}
# INFO - {'layer': 22, 'module': 'self_attn.o_proj', 'avg_loss': '2.3985', 'time': '1.1897'}
# INFO - {'layer': 22, 'module': 'mlp.gate_up_proj', 'avg_loss': '20.2661', 'time': '1.2662'}
# INFO - {'layer': 22, 'module': 'mlp.down_proj', 'avg_loss': '11.3656', 'time': '3.4795'}
# INFO - {'layer': 23, 'module': 'self_attn.qkv_proj', 'avg_loss': '24.5657', 'time': '1.2512'}
# INFO - {'layer': 23, 'module': 'self_attn.o_proj', 'avg_loss': '3.0651', 'time': '1.2249'}
# INFO - {'layer': 23, 'module': 'mlp.gate_up_proj', 'avg_loss': '22.9631', 'time': '1.4072'}
# INFO - {'layer': 23, 'module': 'mlp.down_proj', 'avg_loss': '15.1750', 'time': '3.4353'}
# INFO - {'layer': 24, 'module': 'self_attn.qkv_proj', 'avg_loss': '28.0236', 'time': '1.2584'}
# INFO - {'layer': 24, 'module': 'self_attn.o_proj', 'avg_loss': '3.3871', 'time': '1.2201'}
# INFO - {'layer': 24, 'module': 'mlp.gate_up_proj', 'avg_loss': '26.5902', 'time': '1.4273'}
# INFO - {'layer': 24, 'module': 'mlp.down_proj', 'avg_loss': '19.1169', 'time': '3.5243'}
# INFO - {'layer': 25, 'module': 'self_attn.qkv_proj', 'avg_loss': '29.8331', 'time': '1.2311'}
# INFO - {'layer': 25, 'module': 'self_attn.o_proj', 'avg_loss': '4.5721', 'time': '1.1929'}
# INFO - {'layer': 25, 'module': 'mlp.gate_up_proj', 'avg_loss': '29.8112', 'time': '1.3216'}
# INFO - {'layer': 25, 'module': 'mlp.down_proj', 'avg_loss': '24.6754', 'time': '3.3843'}
# INFO - {'layer': 26, 'module': 'self_attn.qkv_proj', 'avg_loss': '34.0795', 'time': '1.2343'}
# INFO - {'layer': 26, 'module': 'self_attn.o_proj', 'avg_loss': '4.8549', 'time': '1.2437'}
# INFO - {'layer': 26, 'module': 'mlp.gate_up_proj', 'avg_loss': '33.2029', 'time': '1.2715'}
# INFO - {'layer': 26, 'module': 'mlp.down_proj', 'avg_loss': '34.0434', 'time': '3.4438'}
# INFO - {'layer': 27, 'module': 'self_attn.qkv_proj', 'avg_loss': '35.3528', 'time': '1.2396'}
# INFO - {'layer': 27, 'module': 'self_attn.o_proj', 'avg_loss': '5.5931', 'time': '1.2065'}
# INFO - {'layer': 27, 'module': 'mlp.gate_up_proj', 'avg_loss': '37.4242', 'time': '1.3020'}
# INFO - {'layer': 27, 'module': 'mlp.down_proj', 'avg_loss': '36.0296', 'time': '3.4423'}
# INFO - {'layer': 28, 'module': 'self_attn.qkv_proj', 'avg_loss': '39.6745', 'time': '1.2437'}
# INFO - {'layer': 28, 'module': 'self_attn.o_proj', 'avg_loss': '5.9618', 'time': '1.2120'}
# INFO - {'layer': 28, 'module': 'mlp.gate_up_proj', 'avg_loss': '41.0127', 'time': '1.2803'}
# INFO - {'layer': 28, 'module': 'mlp.down_proj', 'avg_loss': '41.2711', 'time': '3.4132'}
# INFO - {'layer': 29, 'module': 'self_attn.qkv_proj', 'avg_loss': '41.6779', 'time': '1.2483'}
# INFO - {'layer': 29, 'module': 'self_attn.o_proj', 'avg_loss': '10.1907', 'time': '1.1905'}
# INFO - {'layer': 29, 'module': 'mlp.gate_up_proj', 'avg_loss': '46.4294', 'time': '1.2772'}
# INFO - {'layer': 29, 'module': 'mlp.down_proj', 'avg_loss': '49.9661', 'time': '3.4535'}
# INFO - {'layer': 30, 'module': 'self_attn.qkv_proj', 'avg_loss': '43.8318', 'time': '1.2346'}
# INFO - {'layer': 30, 'module': 'self_attn.o_proj', 'avg_loss': '12.7973', 'time': '1.1895'}
# INFO - {'layer': 30, 'module': 'mlp.gate_up_proj', 'avg_loss': '51.7107', 'time': '1.2548'}
# INFO - {'layer': 30, 'module': 'mlp.down_proj', 'avg_loss': '66.8333', 'time': '3.4360'}
# INFO - {'layer': 31, 'module': 'self_attn.qkv_proj', 'avg_loss': '43.2623', 'time': '1.2422'}
# INFO - {'layer': 31, 'module': 'self_attn.o_proj', 'avg_loss': '12.3272', 'time': '1.2192'}
# INFO - {'layer': 31, 'module': 'mlp.gate_up_proj', 'avg_loss': '54.0788', 'time': '1.2852'}
# INFO - {'layer': 31, 'module': 'mlp.down_proj', 'avg_loss': '65.8378', 'time': '3.4301'}
# INFO - {'layer': 32, 'module': 'self_attn.qkv_proj', 'avg_loss': '36.1396', 'time': '1.2326'}
# INFO - {'layer': 32, 'module': 'self_attn.o_proj', 'avg_loss': '13.4512', 'time': '1.2076'}
# INFO - {'layer': 32, 'module': 'mlp.gate_up_proj', 'avg_loss': '50.9153', 'time': '1.3078'}
# INFO - {'layer': 32, 'module': 'mlp.down_proj', 'avg_loss': '105.2656', 'time': '3.4324'}
# INFO - Packing model...
# INFO:gptqmodel.utils.model:Packing model...
# Packing model.layers.31.mlp.down_proj: 100%|██████████| 128/128 [03:00<00:00,  1.41s/it]
# INFO - Model packed.
# INFO:gptqmodel.utils.model:Model packed.
# Quantization complete!
# Saving quantized model...
# Saving quantized model complete!
# INFO - Compatibility: converting `checkpoint_format` from `gptq` to `gptq_v2`.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1259: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# What is the capital of Jamaica?
#
# # Answer: The capital of Jamaica
# Filter:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Perplexity: - :   0%|          | 0/1875 [00:00<?, ?it/s]We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# Perplexity: 10.1343: 100%|██████████| 1875/1875 [03:47<00:00,  8.23it/s]
# Quantized Model Phi-3-mini-128k-instruct-4bit-128g avg PPL is 10.257711216714144
